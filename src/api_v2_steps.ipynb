# %%
import os
import requests
import pandas as pd

# parâmetros
symbol = 'BCP.LS'

# Obter a API Key do ambiente
api_key = os.environ.get("API_KEY")
if not api_key:
    raise ValueError("A API Key não está definida. Configure a variável de ambiente 'API_KEY'.")

# Endpoint da API
url = 'https://www.alphavantage.co/query'

params = {
    'function': 'TIME_SERIES_MONTHLY_ADJUSTED',
    'symbol': symbol,
    'apikey': api_key,
    'datatype': 'json'
}

# %%
#fazendo a solicitação à API
response = requests.get(url, params=params)
data = response.json()

if "Monthly Adjusted Time Series" not in data:
    print("Erro: Não foram encontrados dados para o símbolo fornecido.")
else: None

# %%
response
# Out:
# <Response [200]>

# %%
data
# Out:
# {'Meta Data': {'1. Information': 'Monthly Adjusted Prices and Volumes',
#   '2. Symbol': 'BCP.LS',
#   '3. Last Refreshed': '2025-02-07',
#   '4. Time Zone': 'US/Eastern'},
#  'Monthly Adjusted Time Series': {'2025-02-07': {'1. open': '0.4919',
#    '2. high': '0.5088',
#    '3. low': '0.4911',
#    '4. close': '0.5008',
#    '5. adjusted close': '0.5008',
#    '6. volume': '247712741',
#    '7. dividend amount': '0.0000'},
#   '2025-01-31': {'1. open': '0.4665',
#    '2. high': '0.5226',
#    '3. low': '0.4435',
#    '4. close': '0.5054',
#    '5. adjusted close': '0.5054',
#    '6. volume': '1591983949',
#    '7. dividend amount': '0.0000'},
#   '2024-12-31': {'1. open': '0.4448',
#    '2. high': '0.4674',
#    '3. low': '0.4325',
#    '4. close': '0.4647',
#    '5. adjusted close': '0.4647',
#    '6. volume': '960959277',
#    '7. dividend amount': '0.0000'},
#   '2024-11-29': {'1. open': '0.4632',
#    '2. high': '0.4665',
#    '3. low': '0.4335',
#    '4. close': '0.4478',
#    '5. adjusted close': '0.4478',
#    '6. volume': '1110365383',
#    '7. dividend amount': '0.0000'},
#   '2024-10-31': {'1. open': '0.4060',
#    '2. high': '0.4679',
#    '3. low': '0.3853',
#    '4. close': '0.4634',
#    '5. adjusted close': '0.4634',
#    '6. volume': '1465600221',
#    '7. dividend amount': '0.0000'},
#   '2024-09-30': {'1. open': '0.4189',
#    '2. high': '0.4242',
#    '3. low': '0.3990',
#    '4. close': '0.4054',
#    '5. adjusted close': '0.4054',
#    '6. volume': '1144027755',
#    '7. dividend amount': '0.0000'},
#   '2024-08-30': {'1. open': '0.3934',
#    '2. high': '0.4170',
#    '3. low': '0.3400',
#    '4. close': '0.4159',
#    '5. adjusted close': '0.4159',
#    '6. volume': '1405588344',
#    '7. dividend amount': '0.0000'},
#   '2024-07-31': {'1. open': '0.3425',
#    '2. high': '0.4024',
#    '3. low': '0.3423',
#    '4. close': '0.3898',
#    '5. adjusted close': '0.3898',
#    '6. volume': '1457378829',
#    '7. dividend amount': '0.0000'},
#   '2024-06-28': {'1. open': '0.3780',
#    '2. high': '0.3796',
#    '3. low': '0.3163',
#    '4. close': '0.3366',
#    '5. adjusted close': '0.3366',
#    '6. volume': '1442604119',
#    '7. dividend amount': '0.0170'},
#   '2024-05-31': {'1. open': '0.3302',
#    '2. high': '0.3740',
#    '3. low': '0.3249',
#    '4. close': '0.3717',
#    '5. adjusted close': '0.3528',
#    '6. volume': '1847345971',
#    '7. dividend amount': '0.0000'},
#   '2024-04-30': {'1. open': '0.3120',
#    '2. high': '0.3319',
#    '3. low': '0.2882',
#    '4. close': '0.3286',
#    '5. adjusted close': '0.3119',
#    '6. volume': '1637814003',
#    '7. dividend amount': '0.0000'},
#   '2024-03-28': {'1. open': '0.2697',
#    '2. high': '0.3137',
#    '3. low': '0.2581',
#    '4. close': '0.3126',
#    '5. adjusted close': '0.2967',
#    '6. volume': '1415965416',
#    '7. dividend amount': '0.0000'},
#   '2024-02-29': {'1. open': '0.2660',
#    '2. high': '0.2848',
#    '3. low': '0.2533',
#    '4. close': '0.2670',
#    '5. adjusted close': '0.2534',
#    '6. volume': '1164828485',
#    '7. dividend amount': '0.0000'},
#   '2024-01-31': {'1. open': '0.2759',
#    '2. high': '0.3150',
#    '3. low': '0.2628',
#    '4. close': '0.2701',
#    '5. adjusted close': '0.2563',
#    '6. volume': '1760691249',
#    '7. dividend amount': '0.0000'},
#   '2023-12-29': {'1. open': '0.3087',
#    '2. high': '0.3343',
#    '3. low': '0.2651',
#    '4. close': '0.2744',
#    '5. adjusted close': '0.2604',
#    '6. volume': '2182095029',
#    '7. dividend amount': '0.0000'},
#   '2023-11-30': {'1. open': '0.2920',
#    '2. high': '0.3105',
#    '3. low': '0.2747',
#    '4. close': '0.3082',
#    '5. adjusted close': '0.2925',
#    '6. volume': '1935268892',
#    '7. dividend amount': '0.0000'},
#   '2023-10-31': {'1. open': '0.2614',
#    '2. high': '0.2945',
#    '3. low': '0.2558',
#    '4. close': '0.2896',
#    '5. adjusted close': '0.2748',
#    '6. volume': '1688609087',
#    '7. dividend amount': '0.0000'},
#   '2023-09-29': {'1. open': '0.2578',
#    '2. high': '0.2682',
#    '3. low': '0.2380',
#    '4. close': '0.2604',
#    '5. adjusted close': '0.2471',
#    '6. volume': '1370997389',
#    '7. dividend amount': '0.0000'},
#   '2023-08-31': {'1. open': '0.2483',
#    '2. high': '0.2608',
#    '3. low': '0.2350',
#    '4. close': '0.2574',
#    '5. adjusted close': '0.2443',
#    '6. volume': '1064070483',
#    '7. dividend amount': '0.0000'},
#   '2023-07-31': {'1. open': '0.2200',
#    '2. high': '0.2685',
#    '3. low': '0.2164',
#    '4. close': '0.2483',
#    '5. adjusted close': '0.2357',
#    '6. volume': '1472832105',
#    '7. dividend amount': '0.0000'},
#   '2023-06-30': {'1. open': '0.2070',
#    '2. high': '0.2262',
#    '3. low': '0.2011',
#    '4. close': '0.2196',
#    '5. adjusted close': '0.2084',
#    '6. volume': '1003213260',
#    '7. dividend amount': '0.0000'},
#   '2023-05-31': {'1. open': '0.2342',
#    '2. high': '0.2369',
#    '3. low': '0.2048',
#    '4. close': '0.2056',
#    '5. adjusted close': '0.1951',
#    '6. volume': '1414338949',
#    '7. dividend amount': '0.0000'},
#   '2023-04-28': {'1. open': '0.2027',
#    '2. high': '0.2414',
#    '3. low': '0.2010',
#    '4. close': '0.2330',
#    '5. adjusted close': '0.2211',
#    '6. volume': '1669206668',
#    '7. dividend amount': '0.0000'},
#   '2023-03-31': {'1. open': '0.2300',
#    '2. high': '0.2322',
#    '3. low': '0.1694',
#    '4. close': '0.2040',
#    '5. adjusted close': '0.1936',
#    '6. volume': '2672050356',
#    '7. dividend amount': '0.0000'},
#   '2023-02-28': {'1. open': '0.1960',
#    '2. high': '0.2344',
#    '3. low': '0.1914',
#    '4. close': '0.2282',
#    '5. adjusted close': '0.2166',
#    '6. volume': '2296614328',
#    '7. dividend amount': '0.0000'},
#   '2023-01-31': {'1. open': '0.1480',
#    '2. high': '0.1970',
#    '3. low': '0.1476',
#    '4. close': '0.1953',
#    '5. adjusted close': '0.1854',
#    '6. volume': '2581721996',
#    '7. dividend amount': '0.0000'},
#   '2022-12-30': {'1. open': '0.1539',
#    '2. high': '0.1539',
#    '3. low': '0.1397',
#    '4. close': '0.1464',
#    '5. adjusted close': '0.1389',
#    '6. volume': '1087718428',
#    '7. dividend amount': '0.0000'},
#   '2022-11-30': {'1. open': '0.1470',
#    '2. high': '0.1599',
#    '3. low': '0.1422',
#    '4. close': '0.1527',
#    '5. adjusted close': '0.1449',
#    '6. volume': '1811178991',
#    '7. dividend amount': '0.0000'},
#   '2022-10-31': {'1. open': '0.1208',
#    '2. high': '0.1466',
#    '3. low': '0.1184',
#    '4. close': '0.1444',
#    '5. adjusted close': '0.1370',
#    '6. volume': '1638890802',
#    '7. dividend amount': '0.0000'},
#   '2022-09-30': {'1. open': '0.1438',
#    '2. high': '0.1585',
#    '3. low': '0.1205',
#    '4. close': '0.1218',
#    '5. adjusted close': '0.1156',
#    '6. volume': '1788110626',
#    '7. dividend amount': '0.0000'},
#   '2022-08-31': {'1. open': '0.1440',
#    '2. high': '0.1579',
#    '3. low': '0.1390',
#    '4. close': '0.1452',
#    '5. adjusted close': '0.1378',
#    '6. volume': '1094158962',
#    '7. dividend amount': '0.0000'},
#   '2022-07-29': {'1. open': '0.1647',
#    '2. high': '0.1676',
#    '3. low': '0.1330',
#    '4. close': '0.1445',
#    '5. adjusted close': '0.1371',
#    '6. volume': '1932200885',
#    '7. dividend amount': '0.0000'},
#   '2022-06-30': {'1. open': '0.1920',
#    '2. high': '0.1995',
#    '3. low': '0.1628',
#    '4. close': '0.1650',
#    '5. adjusted close': '0.1566',
#    '6. volume': '2183997844',
#    '7. dividend amount': '0.0009'},
#   '2022-05-31': {'1. open': '0.1470',
#    '2. high': '0.1983',
#    '3. low': '0.1405',
#    '4. close': '0.1918',
#    '5. adjusted close': '0.1812',
#    '6. volume': '2446855406',
#    '7. dividend amount': '0.0000'},
#   '2022-04-29': {'1. open': '0.1731',
#    '2. high': '0.1774',
#    '3. low': '0.1461',
#    '4. close': '0.1480',
#    '5. adjusted close': '0.1398',
#    '6. volume': '1854853379',
#    '7. dividend amount': '0.0000'},
#   '2022-03-31': {'1. open': '0.1653',
#    '2. high': '0.1775',
#    '3. low': '0.1200',
#    '4. close': '0.1731',
#    '5. adjusted close': '0.1635',
#    '6. volume': '3811265641',
#    '7. dividend amount': '0.0000'},
#   '2022-02-28': {'1. open': '0.1524',
#    '2. high': '0.2030',
#    '3. low': '0.1506',
#    '4. close': '0.1651',
#    '5. adjusted close': '0.1560',
#    '6. volume': '2367357121',
#    '7. dividend amount': '0.0000'},
#   '2022-01-31': {'1. open': '0.1420',
#    '2. high': '0.1742',
#    '3. low': '0.1418',
#    '4. close': '0.1505',
#    '5. adjusted close': '0.1422',
#    '6. volume': '1700129950',
#    '7. dividend amount': '0.0000'},
#   '2021-12-31': {'1. open': '0.1446',
#    '2. high': '0.1503',
#    '3. low': '0.1271',
#    '4. close': '0.1409',
#    '5. adjusted close': '0.1331',
#    '6. volume': '1072792607',
#    '7. dividend amount': '0.0000'},
#   '2021-11-30': {'1. open': '0.1565',
#    '2. high': '0.1628',
#    '3. low': '0.1400',
#    '4. close': '0.1435',
#    '5. adjusted close': '0.1356',
#    '6. volume': '1390418477',
#    '7. dividend amount': '0.0000'},
#   '2021-10-29': {'1. open': '0.1536',
#    '2. high': '0.1749',
#    '3. low': '0.1510',
#    '4. close': '0.1561',
#    '5. adjusted close': '0.1475',
#    '6. volume': '1789544724',
#    '7. dividend amount': '0.0000'},
#   '2021-09-30': {'1. open': '0.1320',
#    '2. high': '0.1580',
#    '3. low': '0.1224',
#    '4. close': '0.1567',
#    '5. adjusted close': '0.1480',
#    '6. volume': '1360235858',
#    '7. dividend amount': '0.0000'},
#   '2021-08-31': {'1. open': '0.1210',
#    '2. high': '0.1347',
#    '3. low': '0.1192',
#    '4. close': '0.1312',
#    '5. adjusted close': '0.1239',
#    '6. volume': '797888631',
#    '7. dividend amount': '0.0000'},
#   '2021-07-30': {'1. open': '0.1350',
#    '2. high': '0.1389',
#    '3. low': '0.1162',
#    '4. close': '0.1200',
#    '5. adjusted close': '0.1134',
#    '6. volume': '917190683',
#    '7. dividend amount': '0.0000'},
#   '2021-06-30': {'1. open': '0.1600',
#    '2. high': '0.1645',
#    '3. low': '0.1321',
#    '4. close': '0.1350',
#    '5. adjusted close': '0.1275',
#    '6. volume': '823689472',
#    '7. dividend amount': '0.0000'},
#   '2021-05-31': {'1. open': '0.1241',
#    '2. high': '0.1738',
#    '3. low': '0.1228',
#    '4. close': '0.1591',
#    '5. adjusted close': '0.1503',
#    '6. volume': '1548186922',
#    '7. dividend amount': '0.0000'},
#   '2021-04-30': {'1. open': '0.1162',
#    '2. high': '0.1284',
#    '3. low': '0.1110',
#    '4. close': '0.1245',
#    '5. adjusted close': '0.1176',
#    '6. volume': '1018353469',
#    '7. dividend amount': '0.0000'},
#   '2021-03-31': {'1. open': '0.1191',
#    '2. high': '0.1225',
#    '3. low': '0.1125',
#    '4. close': '0.1161',
#    '5. adjusted close': '0.1097',
#    '6. volume': '1107569187',
#    '7. dividend amount': '0.0000'},
#   '2021-02-26': {'1. open': '0.1154',
#    '2. high': '0.1287',
#    '3. low': '0.1134',
#    '4. close': '0.1172',
#    '5. adjusted close': '0.1107',
#    '6. volume': '1041416698',
#    '7. dividend amount': '0.0000'},
#   '2021-01-29': {'1. open': '0.1243',
#    '2. high': '0.1494',
#    '3. low': '0.1088',
#    '4. close': '0.1142',
#    '5. adjusted close': '0.1079',
#    '6. volume': '1121892247',
#    '7. dividend amount': '0.0000'},
#   '2020-12-31': {'1. open': '0.1192',
#    '2. high': '0.1305',
#    '3. low': '0.1130',
#    '4. close': '0.1232',
#    '5. adjusted close': '0.1164',
#    '6. volume': '912170318',
#    '7. dividend amount': '0.0000'},
#   '2020-11-30': {'1. open': '0.0754',
#    '2. high': '0.1233',
#    '3. low': '0.0735',
#    '4. close': '0.1185',
#    '5. adjusted close': '0.1119',
#    '6. volume': '1390024267',
#    '7. dividend amount': '0.0000'},
#   '2020-10-30': {'1. open': '0.0807',
#    '2. high': '0.0837',
#    '3. low': '0.0681',
#    '4. close': '0.0754',
#    '5. adjusted close': '0.0712',
#    '6. volume': '693233952',
#    '7. dividend amount': '0.0000'},
#   '2020-09-30': {'1. open': '0.0987',
#    '2. high': '0.0989',
#    '3. low': '0.0785',
#    '4. close': '0.0803',
#    '5. adjusted close': '0.0759',
#    '6. volume': '880649390',
#    '7. dividend amount': '0.0000'},
#   '2020-08-31': {'1. open': '0.0982',
#    '2. high': '0.1078',
#    '3. low': '0.0962',
#    '4. close': '0.0987',
#    '5. adjusted close': '0.0932',
#    '6. volume': '519434924',
#    '7. dividend amount': '0.0000'},
#   '2020-07-31': {'1. open': '0.1068',
#    '2. high': '0.1124',
#    '3. low': '0.0967',
#    '4. close': '0.0982',
#    '5. adjusted close': '0.0928',
#    '6. volume': '947865556',
#    '7. dividend amount': '0.0000'},
#   '2020-06-30': {'1. open': '0.0998',
#    '2. high': '0.1220',
#    '3. low': '0.0991',
#    '4. close': '0.1070',
#    '5. adjusted close': '0.1011',
#    '6. volume': '1750697749',
#    '7. dividend amount': '0.0000'},
#   '2020-05-29': {'1. open': '0.0995',
#    '2. high': '0.1037',
#    '3. low': '0.0846',
#    '4. close': '0.0985',
#    '5. adjusted close': '0.0930',
#    '6. volume': '1472555272',
#    '7. dividend amount': '0.0000'},
#   '2020-04-30': {'1. open': '0.1012',
#    '2. high': '0.1080',
#    '3. low': '0.0890',
#    '4. close': '0.1020',
#    '5. adjusted close': '0.0963',
#    '6. volume': '1711254946',
#    '7. dividend amount': '0.0000'},
#   '2020-03-31': {'1. open': '0.1668',
#    '2. high': '0.1673',
#    '3. low': '0.0997',
#    '4. close': '0.1025',
#    '5. adjusted close': '0.0968',
#    '6. volume': '2120737194',
#    '7. dividend amount': '0.0000'},
#   '2020-02-28': {'1. open': '0.1920',
#    '2. high': '0.2027',
#    '3. low': '0.1613',
#    '4. close': '0.1625',
#    '5. adjusted close': '0.1535',
#    '6. volume': '709772257',
#    '7. dividend amount': '0.0000'},
#   '2020-01-31': {'1. open': '0.2034',
#    '2. high': '0.2135',
#    '3. low': '0.1814',
#    '4. close': '0.1917',
#    '5. adjusted close': '0.1811',
#    '6. volume': '690415644',
#    '7. dividend amount': '0.0000'},
#   '2019-12-31': {'1. open': '0.1962',
#    '2. high': '0.2071',
#    '3. low': '0.1882',
#    '4. close': '0.2028',
#    '5. adjusted close': '0.1916',
#    '6. volume': '597186795',
#    '7. dividend amount': '0.0000'},
#   '2019-11-29': {'1. open': '0.2033',
#    '2. high': '0.2235',
#    '3. low': '0.1960',
#    '4. close': '0.1960',
#    '5. adjusted close': '0.1851',
#    '6. volume': '777597492',
#    '7. dividend amount': '0.0000'},
#   '2019-10-31': {'1. open': '0.1907',
#    '2. high': '0.2095',
#    '3. low': '0.1810',
#    '4. close': '0.2030',
#    '5. adjusted close': '0.1918',
#    '6. volume': '989377715',
#    '7. dividend amount': '0.0000'},
#   '2019-09-30': {'1. open': '0.1936',
#    '2. high': '0.2154',
#    '3. low': '0.1750',
#    '4. close': '0.1906',
#    '5. adjusted close': '0.1800',
#    '6. volume': '1421721393',
#    '7. dividend amount': '0.0000'},
#   '2019-08-30': {'1. open': '0.2310',
#    '2. high': '0.2331',
#    '3. low': '0.1860',
#    '4. close': '0.1932',
#    '5. adjusted close': '0.1825',
#    '6. volume': '1266685059',
#    '7. dividend amount': '0.0000'},
#   '2019-07-31': {'1. open': '0.2744',
#    '2. high': '0.2892',
#    '3. low': '0.2312',
#    '4. close': '0.2312',
#    '5. adjusted close': '0.2184',
#    '6. volume': '1100736743',
#    '7. dividend amount': '0.0000'},
#   '2019-06-28': {'1. open': '0.2511',
#    '2. high': '0.2724',
#    '3. low': '0.2454',
#    '4. close': '0.2719',
#    '5. adjusted close': '0.2568',
#    '6. volume': '917790386',
#    '7. dividend amount': '0.0020'},
#   '2019-05-31': {'1. open': '0.2489',
#    '2. high': '0.2592',
#    '3. low': '0.2401',
#    '4. close': '0.2520',
#    '5. adjusted close': '0.2361',
#    '6. volume': '856951357',
#    '7. dividend amount': '0.0000'},
#   '2019-04-30': {'1. open': '0.2318',
#    '2. high': '0.2518',
#    '3. low': '0.2293',
#    '4. close': '0.2501',
#    '5. adjusted close': '0.2344',
#    '6. volume': '761425027',
#    '7. dividend amount': '0.0000'},
#   '2019-03-29': {'1. open': '0.2420',
#    '2. high': '0.2465',
#    '3. low': '0.2165',
#    '4. close': '0.2303',
#    '5. adjusted close': '0.2158',
#    '6. volume': '923569827',
#    '7. dividend amount': '0.0000'},
#   '2019-02-28': {'1. open': '0.2408',
#    '2. high': '0.2425',
#    '3. low': '0.2250',
#    '4. close': '0.2410',
#    '5. adjusted close': '0.2258',
#    '6. volume': '803954126',
#    '7. dividend amount': '0.0000'},
#   '2019-01-31': {'1. open': '0.2294',
#    '2. high': '0.2493',
#    '3. low': '0.2240',
#    '4. close': '0.2410',
#    '5. adjusted close': '0.2258',
#    '6. volume': '725198701',
#    '7. dividend amount': '0.0000'},
#   '2018-12-31': {'1. open': '0.2510',
#    '2. high': '0.2555',
#    '3. low': '0.2162',
#    '4. close': '0.2295',
#    '5. adjusted close': '0.2151',
#    '6. volume': '642696277',
#    '7. dividend amount': '0.0000'},
#   '2018-11-30': {'1. open': '0.2382',
#    '2. high': '0.2582',
#    '3. low': '0.2341',
#    '4. close': '0.2481',
#    '5. adjusted close': '0.2325',
#    '6. volume': '775943428',
#    '7. dividend amount': '0.0000'},
#   '2018-10-31': {'1. open': '0.2560',
#    '2. high': '0.2569',
#    '3. low': '0.2148',
#    '4. close': '0.2382',
#    '5. adjusted close': '0.2232',
#    '6. volume': '957359334',
#    '7. dividend amount': '0.0000'},
#   '2018-09-28': {'1. open': '0.2510',
#    '2. high': '0.2664',
#    '3. low': '0.2354',
#    '4. close': '0.2550',
#    '5. adjusted close': '0.2390',
#    '6. volume': '803642149',
#    '7. dividend amount': '0.0000'},
#   '2018-08-31': {'1. open': '0.2692',
#    '2. high': '0.2699',
#    '3. low': '0.2496',
#    '4. close': '0.2508',
#    '5. adjusted close': '0.2350',
#    '6. volume': '601488177',
#    '7. dividend amount': '0.0000'},
#   '2018-07-31': {'1. open': '0.2550',
#    '2. high': '0.2735',
#    '3. low': '0.2501',
#    '4. close': '0.2684',
#    '5. adjusted close': '0.2515',
#    '6. volume': '633078413',
#    '7. dividend amount': '0.0000'},
#   '2018-06-29': {'1. open': '0.2561',
#    '2. high': '0.2791',
#    '3. low': '0.2551',
#    '4. close': '0.2574',
#    '5. adjusted close': '0.2412',
#    '6. volume': '1203604420',
#    '7. dividend amount': '0.0000'},
#   '2018-05-31': {'1. open': '0.2782',
#    '2. high': '0.3042',
#    '3. low': '0.2316',
#    '4. close': '0.2512',
#    '5. adjusted close': '0.2354',
#    '6. volume': '1452309758',
#    '7. dividend amount': '0.0000'},
#   '2018-04-30': {'1. open': '0.2700',
#    '2. high': '0.2941',
#    '3. low': '0.2599',
#    '4. close': '0.2781',
#    '5. adjusted close': '0.2606',
#    '6. volume': '690500707',
#    '7. dividend amount': '0.0000'},
#   '2018-03-29': {'1. open': '0.2940',
#    '2. high': '0.3175',
#    '3. low': '0.2677',
#    '4. close': '0.2720',
#    '5. adjusted close': '0.2549',
#    '6. volume': '1536572067',
#    '7. dividend amount': '0.0000'},
#   '2018-02-28': {'1. open': '0.3220',
#    '2. high': '0.3280',
#    '3. low': '0.2811',
#    '4. close': '0.2950',
#    '5. adjusted close': '0.2764',
#    '6. volume': '1108839819',
#    '7. dividend amount': '0.0000'},
#   '2018-01-31': {'1. open': '0.2728',
#    '2. high': '0.3360',
#    '3. low': '0.2728',
#    '4. close': '0.3221',
#    '5. adjusted close': '0.3018',
#    '6. volume': '1569530871',
#    '7. dividend amount': '0.0000'},
#   '2017-12-29': {'1. open': '0.2571',
#    '2. high': '0.2735',
#    '3. low': '0.2555',
#    '4. close': '0.2720',
#    '5. adjusted close': '0.2549',
#    '6. volume': '1052887203',
#    '7. dividend amount': '0.0000'},
#   '2017-11-30': {'1. open': '0.2578',
#    '2. high': '0.2580',
#    '3. low': '0.2402',
#    '4. close': '0.2575',
#    '5. adjusted close': '0.2413',
#    '6. volume': '975488551',
#    '7. dividend amount': '0.0000'},
#   '2017-10-31': {'1. open': '0.2465',
#    '2. high': '0.2600',
#    '3. low': '0.2375',
#    '4. close': '0.2565',
#    '5. adjusted close': '0.2404',
#    '6. volume': '1641638842',
#    '7. dividend amount': '0.0000'},
#   '2017-09-29': {'1. open': '0.2245',
#    '2. high': '0.2475',
#    '3. low': '0.1855',
#    '4. close': '0.2453',
#    '5. adjusted close': '0.2299',
#    '6. volume': '1994871534',
#    '7. dividend amount': '0.0000'},
#   '2017-08-31': {'1. open': '0.2417',
#    '2. high': '0.2460',
#    '3. low': '0.2115',
#    '4. close': '0.2234',
#    '5. adjusted close': '0.2093',
#    '6. volume': '1067300100',
#    '7. dividend amount': '0.0000'},
#   '2017-07-31': {'1. open': '0.2377',
#    '2. high': '0.2603',
#    '3. low': '0.2341',
#    '4. close': '0.2414',
#    '5. adjusted close': '0.2262',
#    '6. volume': '1440043021',
#    '7. dividend amount': '0.0000'},
#   '2017-06-30': {'1. open': '0.2300',
#    '2. high': '0.2456',
#    '3. low': '0.2181',
#    '4. close': '0.2357',
#    '5. adjusted close': '0.2209',
#    '6. volume': '1949190116',
#    '7. dividend amount': '0.0000'},
#   '2017-05-31': {'1. open': '0.2053',
#    '2. high': '0.2375',
#    '3. low': '0.2016',
#    '4. close': '0.2300',
#    '5. adjusted close': '0.2155',
#    '6. volume': '2101142908',
#    '7. dividend amount': '0.0000'},
#   '2017-04-28': {'1. open': '0.1935',
#    '2. high': '0.2096',
#    '3. low': '0.1732',
#    '4. close': '0.2048',
#    '5. adjusted close': '0.1919',
#    '6. volume': '1361256151',
#    '7. dividend amount': '0.0000'},
#   '2017-03-31': {'1. open': '0.1520',
#    '2. high': '0.2000',
#    '3. low': '0.1491',
#    '4. close': '0.1961',
#    '5. adjusted close': '0.1838',
#    '6. volume': '2318054136',
#    '7. dividend amount': '0.0000'},
#   '2017-02-28': {'1. open': '0.1586',
#    '2. high': '0.1835',
#    '3. low': '0.1327',
#    '4. close': '0.1507',
#    '5. adjusted close': '0.1412',
#    '6. volume': '1571024040',
#    '7. dividend amount': '0.0000'},
#   '2017-01-31': {'1. open': '1.0680',
#    '2. high': '1.1077',
#    '3. low': '0.1409',
#    '4. close': '0.1564',
#    '5. adjusted close': '0.1466',
#    '6. volume': '888231271',
#    '7. dividend amount': '0.0000'},
#   '2016-12-30': {'1. open': '1.1775',
#    '2. high': '1.3930',
#    '3. low': '1.0200',
#    '4. close': '1.0710',
#    '5. adjusted close': '0.1729',
#    '6. volume': '569750983',
#    '7. dividend amount': '0.0000'},
#   '2016-11-30': {'1. open': '1.2169',
#    '2. high': '1.3240',
#    '3. low': '1.0701',
#    '4. close': '1.1800',
#    '5. adjusted close': '0.1904',
#    '6. volume': '286271968',
#    '7. dividend amount': '0.0000'},
#   '2016-10-31': {'1. open': '0.0157',
#    '2. high': '1.3597',
#    '3. low': '0.0151',
#    '4. close': '1.2130',
#    '5. adjusted close': '0.1958',
#    '6. volume': '246570549',
#    '7. dividend amount': '0.0000'},
#   '2016-09-30': {'1. open': '0.0180',
#    '2. high': '0.0192',
#    '3. low': '0.0139',
#    '4. close': '0.0157',
#    '5. adjusted close': '0.1864',
#    '6. volume': '446614456',
#    '7. dividend amount': '0.0000'},
#   '2016-08-31': {'1. open': '0.0215',
#    '2. high': '0.0226',
#    '3. low': '0.0174',
#    '4. close': '0.0180',
#    '5. adjusted close': '0.2179',
#    '6. volume': '305915624',
#    '7. dividend amount': '0.0000'},
#   '2016-07-29': {'1. open': '0.0186',
#    '2. high': '0.0221',
#    '3. low': '0.0174',
#    '4. close': '0.0203',
#    '5. adjusted close': '0.2445',
#    '6. volume': '394342592',
#    '7. dividend amount': '0.0000'},
#   '2016-06-30': {'1. open': '0.0308',
#    '2. high': '0.0308',
#    '3. low': '0.0151',
#    '4. close': '0.0180',
#    '5. adjusted close': '0.2203',
#    '6. volume': '1065115970',
#    '7. dividend amount': '0.0000'},
#   '2016-05-31': {'1. open': '0.0389',
#    '2. high': '0.0401',
#    '3. low': '0.0302',
#    '4. close': '0.0308',
#    '5. adjusted close': '0.3704',
#    '6. volume': '601445969',
#    '7. dividend amount': '0.0000'},
#   '2016-04-29': {'1. open': '0.0354',
#    '2. high': '0.0412',
#    '3. low': '0.0308',
#    '4. close': '0.0389',
#    '5. adjusted close': '0.4685',
#    '6. volume': '626150161',
#    '7. dividend amount': '0.0000'},
#   '2016-03-31': {'1. open': '0.0343',
#    '2. high': '0.0476',
#    '3. low': '0.0343',
#    '4. close': '0.0354',
#    '5. adjusted close': '0.4321',
#    '6. volume': '729412815',
#    '7. dividend amount': '0.0000'},
#   '2016-02-29': {'1. open': '0.0389',
#    '2. high': '0.0401',
#    '3. low': '0.0308',
#    '4. close': '0.0343',
#    '5. adjusted close': '0.4164',
#    '6. volume': '520271341',
#    '7. dividend amount': '0.0000'},
#   '2016-01-29': {'1. open': '0.0482',
#    '2. high': '0.0517',
#    '3. low': '0.0314',
#    '4. close': '0.0389',
#    '5. adjusted close': '0.4709',
#    '6. volume': '480029367',
#    '7. dividend amount': '0.0000'},
#   '2015-12-31': {'1. open': '0.0511',
#    '2. high': '0.0528',
#    '3. low': '0.0459',
#    '4. close': '0.0488',
#    '5. adjusted close': '0.5919',
#    '6. volume': '324156868',
#    '7. dividend amount': '0.0000'},
#   '2015-11-30': {'1. open': '0.0523',
#    '2. high': '0.0581',
#    '3. low': '0.0441',
#    '4. close': '0.0505',
#    '5. adjusted close': '0.6125',
#    '6. volume': '466689514',
#    '7. dividend amount': '0.0000'},
#   '2015-10-30': {'1. open': '0.0447',
#    '2. high': '0.0656',
#    '3. low': '0.0441',
#    '4. close': '0.0523',
#    '5. adjusted close': '0.6331',
#    '6. volume': '643139155',
#    '7. dividend amount': '0.0000'},
#   '2015-09-30': {'1. open': '0.0627',
#    '2. high': '0.0627',
#    '3. low': '0.0406',
#    '4. close': '0.0435',
#    '5. adjusted close': '0.5266',
#    '6. volume': '444923388',
#    '7. dividend amount': '0.0000'},
#   '2015-08-31': {'1. open': '0.0703',
#    '2. high': '0.0714',
#    '3. low': '0.0540',
#    '4. close': '0.0633',
#    '5. adjusted close': '0.7626',
#    '6. volume': '379032950',
#    '7. dividend amount': '0.0000'},
#   '2015-07-31': {'1. open': '0.0784',
#    '2. high': '0.0848',
#    '3. low': '0.0691',
#    '4. close': '0.0703',
#    '5. adjusted close': '0.8473',
#    '6. volume': '465347884',
#    '7. dividend amount': '0.0000'},
#   '2015-06-30': {'1. open': '0.0854',
#    '2. high': '0.0900',
#    '3. low': '0.0737',
#    '4. close': '0.0778',
#    '5. adjusted close': '0.9442',
#    '6. volume': '460216258',
#    '7. dividend amount': '0.0000'},
#   '2015-05-29': {'1. open': '0.0900',
#    '2. high': '0.0941',
#    '3. low': '0.0842',
#    '4. close': '0.0854',
#    '5. adjusted close': '1.0313',
#    '6. volume': '270518408',
#    '7. dividend amount': '0.0000'},
#   '2015-04-30': {'1. open': '0.0952',
#    '2. high': '0.0964',
#    '3. low': '0.0807',
#    '4. close': '0.0888',
#    '5. adjusted close': '1.0785',
#    '6. volume': '337363020',
#    '7. dividend amount': '0.0000'},
#   '2015-03-31': {'1. open': '0.0836',
#    '2. high': '0.0987',
#    '3. low': '0.0824',
#    '4. close': '0.0958',
#    '5. adjusted close': '1.1584',
#    '6. volume': '484505960',
#    '7. dividend amount': '0.0000'},
#   '2015-02-27': {'1. open': '0.0633',
#    '2. high': '0.0848',
#    '3. low': '0.0615',
#    '4. close': '0.0830',
#    '5. adjusted close': '1.0071',
#    '6. volume': '453633566',
#    '7. dividend amount': '0.0000'},
#   '2015-01-30': {'1. open': '0.0674',
#    '2. high': '0.0749',
#    '3. low': '0.0586',
#    '4. close': '0.0633',
#    '5. adjusted close': '0.7626',
#    '6. volume': '520018220',
#    '7. dividend amount': '0.0000'},
#   '2014-12-31': {'1. open': '0.0819',
#    '2. high': '0.0859',
#    '3. low': '0.0644',
#    '4. close': '0.0656',
#    '5. adjusted close': '0.7953',
#    '6. volume': '435651100',
#    '7. dividend amount': '0.0000'},
#   '2014-11-28': {'1. open': '0.0888',
#    '2. high': '0.0900',
#    '3. low': '0.0708',
#    '4. close': '0.0830',
#    '5. adjusted close': '1.0047',
#    '6. volume': '437246436',
#    '7. dividend amount': '0.0000'},
#   '2014-10-31': {'1. open': '0.1033',
#    '2. high': '0.1068',
#    '3. low': '0.0766',
#    '4. close': '0.0900',
#    '5. adjusted close': '1.0894',
#    '6. volume': '642884680',
#    '7. dividend amount': '0.0000'},
#   '2014-09-30': {'1. open': '0.1039',
#    '2. high': '0.1138',
#    '3. low': '0.0993',
#    '4. close': '0.1033',
#    '5. adjusted close': '1.2540',
#    '6. volume': '479994049',
#    '7. dividend amount': '0.0000'},
#   '2014-08-29': {'1. open': '0.1092',
#    '2. high': '0.1109',
#    '3. low': '0.0703',
#    '4. close': '0.1033',
#    '5. adjusted close': '1.2528',
#    '6. volume': '514096040',
#    '7. dividend amount': '0.0000'},
#   '2014-07-31': {'1. open': '0.1150',
#    '2. high': '0.1405',
#    '3. low': '0.0958',
#    '4. close': '0.1074',
#    '5. adjusted close': '1.2976',
#    '6. volume': '743895673',
#    '7. dividend amount': '0.0000'},
#   '2014-06-30': {'1. open': '0.1922',
#    '2. high': '0.2084',
#    '3. low': '0.1440',
#    '4. close': '0.1910',
#    '5. adjusted close': '1.3410',
#    '6. volume': '486355214',
#    '7. dividend amount': '0.0000'},
#   '2014-05-30': {'1. open': '0.2212',
#    '2. high': '0.2305',
#    '3. low': '0.1579',
#    '4. close': '0.1916',
#    '5. adjusted close': '1.3466',
#    '6. volume': '510341989',
#    '7. dividend amount': '0.0000'},
#   '2014-04-30': {'1. open': '0.2288',
#    '2. high': '0.2392',
#    '3. low': '0.2021',
#    '4. close': '0.2189',
#    '5. adjusted close': '1.5384',
#    '6. volume': '364321649',
#    '7. dividend amount': '0.0000'},
#   '2014-03-31': {'1. open': '0.1939',
#    '2. high': '0.2375',
#    '3. low': '0.1881',
#    '4. close': '0.2270',
#    '5. adjusted close': '1.5946',
#    '6. volume': '550453685',
#    '7. dividend amount': '0.0000'},
#   '2014-02-28': {'1. open': '0.1655',
#    '2. high': '0.1997',
#    '3. low': '0.1573',
#    '4. close': '0.1974',
#    '5. adjusted close': '1.3852',
#    '6. volume': '342679209',
#    '7. dividend amount': '0.0000'},
#   '2014-01-31': {'1. open': '0.1695',
#    '2. high': '0.1945',
#    '3. low': '0.1620',
#    '4. close': '0.1661',
#    '5. adjusted close': '1.1661',
#    '6. volume': '571309761',
#    '7. dividend amount': '0.0000'},
#   '2013-12-31': {'1. open': '0.1312',
#    '2. high': '0.1870',
#    '3. low': '0.1295',
#    '4. close': '0.1666',
#    '5. adjusted close': '1.1689',
#    '6. volume': '475481038',
#    '7. dividend amount': '0.0000'},
#   '2013-11-29': {'1. open': '0.1097',
#    '2. high': '0.1353',
#    '3. low': '0.1092',
#    '4. close': '0.1301',
#    '5. adjusted close': '0.9146',
#    '6. volume': '332030543',
#    '7. dividend amount': '0.0000'},
#   '2013-10-31': {'1. open': '0.0952',
#    '2. high': '0.1126',
#    '3. low': '0.0952',
#    '4. close': '0.1103',
#    '5. adjusted close': '0.7741',
#    '6. volume': '369535062',
#    '7. dividend amount': '0.0000'},
#   '2013-09-30': {'1. open': '0.0970',
#    '2. high': '0.0999',
#    '3. low': '0.0929',
#    '4. close': '0.0958',
#    '5. adjusted close': '0.6744',
#    '6. volume': '160769326',
#    '7. dividend amount': '0.0000'},
#   '2013-08-30': {'1. open': '0.0952',
#    '2. high': '0.1097',
#    '3. low': '0.0941',
#    '4. close': '0.0958',
#    '5. adjusted close': '0.6744',
#    '6. volume': '271000934',
#    '7. dividend amount': '0.0000'},
#   '2013-07-31': {'1. open': '0.0958',
#    '2. high': '0.0999',
#    '3. low': '0.0732',
#    '4. close': '0.0941',
#    '5. adjusted close': '0.6603',
#    '6. volume': '400346068',
#    '7. dividend amount': '0.0000'},
#   '2013-06-28': {'1. open': '0.1051',
#    '2. high': '0.1068',
#    '3. low': '0.0848',
#    '4. close': '0.0958',
#    '5. adjusted close': '0.6744',
#    '6. volume': '228653143',
#    '7. dividend amount': '0.0000'},
#   '2013-05-31': {'1. open': '0.1051',
#    '2. high': '0.1109',
#    '3. low': '0.0999',
#    '4. close': '0.1068',
#    '5. adjusted close': '0.7516',
#    '6. volume': '329801875',
#    '7. dividend amount': '0.0000'},
#   '2013-04-30': {'1. open': '0.0952',
#    '2. high': '0.1068',
#    '3. low': '0.0801',
#    '4. close': '0.1051',
#    '5. adjusted close': '0.7376',
#    '6. volume': '462851310',
#    '7. dividend amount': '0.0000'},
#   '2013-03-28': {'1. open': '0.1092',
#    '2. high': '0.1132',
#    '3. low': '0.0912',
#    '4. close': '0.0952',
#    '5. adjusted close': '0.6673',
#    '6. volume': '363806507',
#    '7. dividend amount': '0.0000'},
#   '2013-02-28': {'1. open': '0.0993',
#    '2. high': '0.1173',
#    '3. low': '0.0958',
#    '4. close': '0.1092',
#    '5. adjusted close': '0.7657',
#    '6. volume': '474455334',
#    '7. dividend amount': '0.0000'},
#   '2013-01-31': {'1. open': '0.0772',
#    '2. high': '0.1202',
#    '3. low': '0.0761',
#    '4. close': '0.0993',
#    '5. adjusted close': '0.6954',
#    '6. volume': '700129293',
#    '7. dividend amount': '0.0000'},
#   '2012-12-31': {'1. open': '0.0708',
#    '2. high': '0.0790',
#    '3. low': '0.0703',
#    '4. close': '0.0749',
#    '5. adjusted close': '0.5268',
#    '6. volume': '228890141',
#    '7. dividend amount': '0.0000'},
#   '2012-11-30': {'1. open': '0.0703',
#    '2. high': '0.0732',
#    '3. low': '0.0662',
#    '4. close': '0.0703',
#    '5. adjusted close': '0.4917',
#    '6. volume': '205420895',
#    '7. dividend amount': '0.0000'},
#   '2012-10-31': {'1. open': '0.0650',
#    '2. high': '0.0848',
#    '3. low': '0.0650',
#    '4. close': '0.0703',
#    '5. adjusted close': '0.4917',
#    '6. volume': '456114175',
#    '7. dividend amount': '0.0000'},
#   '2012-09-28': {'1. open': '0.0883',
#    '2. high': '0.0952',
#    '3. low': '0.0557',
#    '4. close': '0.0639',
#    '5. adjusted close': '0.4496',
#    '6. volume': '264753143',
#    '7. dividend amount': '0.0000'},
#   '2012-08-31': {'1. open': '0.0929',
#    '2. high': '0.0993',
#    '3. low': '0.0871',
#    '4. close': '0.0871',
#    '5. adjusted close': '0.3939',
#    '6. volume': '88479635',
#    '7. dividend amount': '0.0000'},
#   '2012-07-31': {'1. open': '0.0999',
#    '2. high': '0.1028',
#    '3. low': '0.0900',
#    '4. close': '0.0941',
#    '5. adjusted close': '0.4256',
#    '6. volume': '65819796',
#    '7. dividend amount': '0.0000'},
#   '2012-06-29': {'1. open': '0.1022',
#    '2. high': '0.1039',
#    '3. low': '0.0732',
#    '4. close': '0.0981',
#    '5. adjusted close': '0.4437',
#    '6. volume': '168476114',
#    '7. dividend amount': '0.0000'},
#   '2012-05-31': {'1. open': '0.1051',
#    '2. high': '0.1179',
#    '3. low': '0.0958',
#    '4. close': '0.1022',
#    '5. adjusted close': '0.4618',
#    '6. volume': '154524180',
#    '7. dividend amount': '0.0000'},
#   '2012-04-30': {'1. open': '0.1388',
#    '2. high': '0.1411',
#    '3. low': '0.1028',
#    '4. close': '0.1063',
#    '5. adjusted close': '0.4799',
#    '6. volume': '192278275',
#    '7. dividend amount': '0.0000'},
#   '2012-03-30': {'1. open': '0.1701',
#    '2. high': '0.1719',
#    '3. low': '0.1370',
#    '4. close': '0.1388',
#    '5. adjusted close': '0.6293',
#    '6. volume': '290358295',
#    '7. dividend amount': '0.0000'},
#   '2012-02-29': {'1. open': '0.1353',
#    '2. high': '0.2189',
#    '3. low': '0.1353',
#    '4. close': '0.1701',
#    '5. adjusted close': '0.7697',
#    '6. volume': '621534870',
#    '7. dividend amount': '0.0000'},
#   '2012-01-31': {'1. open': '0.1382',
#    '2. high': '0.1533',
#    '3. low': '0.1208',
#    '4. close': '0.1353',
#    '5. adjusted close': '0.6112',
#    '6. volume': '407825751',
#    '7. dividend amount': '0.0000'},
#   '2011-12-30': {'1. open': '0.1289',
#    '2. high': '0.1440',
#    '3. low': '0.1039',
#    '4. close': '0.1359',
#    '5. adjusted close': '0.6157',
#    '6. volume': '284274733',
#    '7. dividend amount': '0.0000'},
#   '2011-11-30': {'1. open': '0.1521',
#    '2. high': '0.1678',
#    '3. low': '0.0970',
#    '4. close': '0.1272',
#    '5. adjusted close': '0.5750',
#    '6. volume': '621197415',
#    '7. dividend amount': '0.0000'},
#   '2011-10-31': {'1. open': '0.1910',
#    '2. high': '0.1910',
#    '3. low': '0.1510',
#    '4. close': '0.1550',
#    '5. adjusted close': '0.7018',
#    '6. volume': '187402727',
#    '7. dividend amount': '0.0000'},
#   '2011-09-30': {'1. open': '0.2531',
#    '2. high': '0.2537',
#    '3. low': '0.1701',
#    '4. close': '0.1951',
#    '5. adjusted close': '0.8829',
#    '6. volume': '221974961',
#    '7. dividend amount': '0.0000'},
#   '2011-08-31': {'1. open': '0.3269',
#    '2. high': '0.3310',
#    '3. low': '0.2433',
#    '4. close': '0.2531',
#    '5. adjusted close': '1.1454',
#    '6. volume': '203793207',
#    '7. dividend amount': '0.0000'},
#   '2011-07-29': {'1. open': '0.4128',
#    '2. high': '0.4140',
#    '3. low': '0.2920',
#    '4. close': '0.3222',
#    '5. adjusted close': '1.4578',
#    '6. volume': '252683167',
#    '7. dividend amount': '0.0000'},
#   '2011-06-30': {'1. open': '0.4709',
#    '2. high': '0.4918',
#    '3. low': '0.3791',
#    '4. close': '0.4099',
#    '5. adjusted close': '1.8562',
#    '6. volume': '171825428',
#    '7. dividend amount': '0.0000'},
#   '2011-05-31': {'1. open': '0.5400',
#    '2. high': '0.5748',
#    '3. low': '0.4569',
#    '4. close': '0.4807',
#    '5. adjusted close': '2.1777',
#    '6. volume': '90595278',
#    '7. dividend amount': '0.0000'},
#   '2011-04-29': {'1. open': '0.5760',
#    '2. high': '0.6247',
#    '3. low': '0.5231',
#    '4. close': '0.5388',
#    '5. adjusted close': '2.3644',
#    '6. volume': '68733655',
#    '7. dividend amount': '0.0000'},
#   '2011-03-31': {'1. open': '0.6468',
#    '2. high': '0.6573',
#    '3. low': '0.5719',
#    '4. close': '0.5760',
#    '5. adjusted close': '2.4202',
#    '6. volume': '107975133',
#    '7. dividend amount': '0.0000'},
#   '2011-02-28': {'1. open': '0.5911',
#    '2. high': '0.6480',
#    '3. low': '0.5858',
#    '4. close': '0.6462',
#    '5. adjusted close': '2.7144',
#    '6. volume': '114187972',
#    '7. dividend amount': '0.0000'},
#   '2011-01-31': {'1. open': '0.5899',
#    '2. high': '0.6300',
#    '3. low': '0.5051',
#    '4. close': '0.5870',
#    '5. adjusted close': '2.4665',
#    '6. volume': '117176728',
#    '7. dividend amount': '0.0000'},
#   '2010-12-31': {'1. open': '0.5899',
#    '2. high': '0.6369',
#    '3. low': '0.5818',
#    '4. close': '0.5818',
#    '5. adjusted close': '2.4455',
#    '6. volume': '69198896',
#    '7. dividend amount': '0.0000'},
#   '2010-11-30': {'1. open': '0.6631',
#    '2. high': '0.6683',
#    '3. low': '0.5858',
#    '4. close': '0.5882',
#    '5. adjusted close': '2.4707',
#    '6. volume': '132796405',
#    '7. dividend amount': '0.0000'},
#   '2010-10-29': {'1. open': '0.6398',
#    '2. high': '0.6770',
#    '3. low': '0.6288',
#    '4. close': '0.6538',
#    '5. adjusted close': '2.7480',
#    '6. volume': '101721192',
#    '7. dividend amount': '0.0000'},
#   '2010-09-30': {'1. open': '0.6323',
#    '2. high': '0.6619',
#    '3. low': '0.6067',
#    '4. close': '0.6393',
#    '5. adjusted close': '2.6850',
#    '6. volume': '121107707',
#    '7. dividend amount': '0.0000'},
#   '2010-08-31': {'1. open': '0.6660',
#    '2. high': '0.7043',
#    '3. low': '0.6021',
#    '4. close': '0.6300',
#    '5. adjusted close': '2.6471',
#    '6. volume': '108724957',
#    '7. dividend amount': '0.0000'},
#   '2010-07-30': {'1. open': '0.6108',
#    '2. high': '0.7043',
#    '3. low': '0.6009',
#    '4. close': '0.6642',
#    '5. adjusted close': '2.7900',
#    '6. volume': '150467516',
#    '7. dividend amount': '0.0000'},
#   '2010-06-30': {'1. open': '0.6410',
#    '2. high': '0.6799',
#    '3. low': '0.5858',
#    '4. close': '0.6201',
#    '5. adjusted close': '2.6051',
#    '6. volume': '126721509',
#    '7. dividend amount': '0.0000'},
#   '2010-05-31': {'1. open': '0.7101',
#    '2. high': '0.7351',
#    '3. low': '0.5998',
#    '4. close': '0.6439',
#    '5. adjusted close': '2.7060',
#    '6. volume': '195928008',
#    '7. dividend amount': '0.0000'},
#   '2010-04-30': {'1. open': '0.8227',
#    '2. high': '0.8529',
#    '3. low': '0.5551',
#    '4. close': '0.7031',
#    '5. adjusted close': '2.9539',
#    '6. volume': '162849155',
#    '7. dividend amount': '0.0852'},
#   '2010-03-31': {'1. open': '0.7502',
#    '2. high': '0.8570',
#    '3. low': '0.7368',
#    '4. close': '0.8239',
#    '5. adjusted close': '3.3820',
#    '6. volume': '94613806',
#    '7. dividend amount': '0.0000'},
#   '2010-02-26': {'1. open': '0.7891',
#    '2. high': '0.8140',
#    '3. low': '0.6758',
#    '4. close': '0.7438',
#    '5. adjusted close': '3.0536',
#    '6. volume': '140931407',
#    '7. dividend amount': '0.0000'},
#   '2010-01-29': {'1. open': '0.8500',
#    '2. high': '0.9330',
#    '3. low': '0.7629',
#    '4. close': '0.7850',
#    '5. adjusted close': '3.2219',
#    '6. volume': '118689797',
#    '7. dividend amount': '0.0000'},
#   '2009-12-31': {'1. open': '0.8872',
#    '2. high': '0.8959',
#    '3. low': '0.7612',
#    '4. close': '0.8448',
#    '5. adjusted close': '3.4682',
#    '6. volume': '83040849',
#    '7. dividend amount': '0.0000'},
#   '2009-11-30': {'1. open': '0.9690',
#    '2. high': '0.9847',
#    '3. low': '0.8732',
#    '4. close': '0.8820',
#    '5. adjusted close': '3.6200',
#    '6. volume': '70837745',
#    '7. dividend amount': '0.0000'},
#   '2009-10-30': {'1. open': '1.0138',
#    '2. high': '1.0747',
#    '3. low': '0.9127',
#    '4. close': '0.9702',
#    '5. adjusted close': '3.9812',
#    '6. volume': '98835109',
#    '7. dividend amount': '0.0000'},
#   '2009-09-30': {'1. open': '0.9162',
#    '2. high': '1.0463',
#    '3. low': '0.8802',
#    '4. close': '1.0109',
#    '5. adjusted close': '4.1495',
#    '6. volume': '103163183',
#    '7. dividend amount': '0.0000'},
#   '2009-08-31': {'1. open': '0.7531',
#    '2. high': '0.9638',
#    '3. low': '0.7531',
#    '4. close': '0.9127',
#    '5. adjusted close': '3.7473',
#    '6. volume': '117204536',
#    '7. dividend amount': '0.0000'},
#   '2009-07-31': {'1. open': '0.7200',
#    '2. high': '0.7751',
#    '3. low': '0.7049',
#    '4. close': '0.7507',
#    '5. adjusted close': '3.0824',
#    '6. volume': '47520568',
#    '7. dividend amount': '0.0000'},
#   '2009-06-30': {'1. open': '0.7687',
#    '2. high': '0.7931',
#    '3. low': '0.6962',
#    '4. close': '0.7240',
#    '5. adjusted close': '2.9715',
#    '6. volume': '60188070',
#    '7. dividend amount': '0.0000'},
#   '2009-05-29': {'1. open': '0.7322',
#    '2. high': '0.8552',
#    '3. low': '0.6950',
#    '4. close': '0.7560',
#    '5. adjusted close': '3.1029',
#    '6. volume': '103286578',
#    '7. dividend amount': '0.0000'},
#   '2009-04-30': {'1. open': '0.6201',
#    '2. high': '0.7653',
#    '3. low': '0.5998',
#    '4. close': '0.7101',
#    '5. adjusted close': '2.9141',
#    '6. volume': '116728156',
#    '7. dividend amount': '0.0762'},
#   '2009-03-31': {'1. open': '0.6108',
#    '2. high': '0.6549',
#    '3. low': '0.5562',
#    '4. close': '0.6178',
#    '5. adjusted close': '2.4685',
#    '6. volume': '70584767',
#    '7. dividend amount': '0.0000'},
#   '2009-02-27': {'1. open': '0.7931',
#    '2. high': '0.8001',
#    '3. low': '0.5568',
#    '4. close': '0.6398',
#    '5. adjusted close': '2.5563',
#    '6. volume': '48455763',
#    '7. dividend amount': '0.0000'},
#   '2009-01-30': {'1. open': '0.8140',
#    '2. high': '0.8721',
#    '3. low': '0.7362',
#    '4. close': '0.8001',
#    '5. adjusted close': '3.1954',
#    '6. volume': '34726108',
#    '7. dividend amount': '0.0000'},
#   '2008-12-31': {'1. open': '0.8198',
#    '2. high': '0.8709',
#    '3. low': '0.7612',
#    '4. close': '0.8152',
#    '5. adjusted close': '3.2553',
#    '6. volume': '31347568',
#    '7. dividend amount': '0.0000'},
#   '2008-11-28': {'1. open': '0.9098',
#    '2. high': '0.9278',
#    '3. low': '0.6851',
#    '4. close': '0.7989',
#    '5. adjusted close': '3.1914',
#    '6. volume': '47785128',
#    '7. dividend amount': '0.0000'},
#   '2008-10-31': {'1. open': '1.1577',
#    '2. high': '1.1618',
#    '3. low': '0.8448',
#    '4. close': '0.9127',
#    '5. adjusted close': '3.6468',
#    '6. volume': '74451114',
#    '7. dividend amount': '0.0000'},
#   '2008-09-30': {'1. open': '1.1688',
#    '2. high': '1.3598',
#    '3. low': '1.0701',
#    '4. close': '1.1421',
#    '5. adjusted close': '4.5615',
#    '6. volume': '109792955',
#    '7. dividend amount': '0.0000'},
#   '2008-08-29': {'1. open': '1.1252',
#    '2. high': '1.1903',
#    '3. low': '1.1049',
#    '4. close': '1.1798',
#    '5. adjusted close': '4.7132',
#    '6. volume': '58856581',
#    '7. dividend amount': '0.0000'},
#   '2008-07-31': {'1. open': '1.3749',
#    '2. high': '1.3801',
#    '3. low': '1.0248',
#    '4. close': '1.1450',
#    '5. adjusted close': '4.5734',
#    '6. volume': '137732193',
#    '7. dividend amount': '0.0000'},
#   '2008-06-30': {'1. open': '1.6298',
#    '2. high': '1.6698',
#    '3. low': '1.3552',
#    '4. close': '1.3749',
#    '5. adjusted close': '5.4921',
#    '6. volume': '81871507',
#    '7. dividend amount': '0.0000'},
#   '2008-05-30': {'1. open': '1.8400',
#    '2. high': '1.8649',
#    '3. low': '1.6100',
#    '4. close': '1.6350',
#    '5. adjusted close': '6.5306',
#    '6. volume': '64541004',
#    '7. dividend amount': '0.0000'},
#   '2008-04-30': {'1. open': '2.0502',
#    '2. high': '2.2400',
#    '3. low': '1.7848',
#    '4. close': '1.8051',
#    '5. adjusted close': '7.2097',
#    '6. volume': '111050037',
#    '7. dividend amount': '0.0000'},
#   '2008-03-31': {'1. open': '1.8853',
#    '2. high': '2.0902',
#    '3. low': '1.7053',
#    '4. close': '2.0600',
#    '5. adjusted close': '7.4042',
#    '6. volume': '66191329',
#    '7. dividend amount': '0.0000'},
#   '2008-02-29': {'1. open': '2.1001',
#    '2. high': '2.1047',
#    '3. low': '1.6751',
#    '4. close': '1.9102',
#    '5. adjusted close': '6.8651',
#    '6. volume': '72515359',
#    '7. dividend amount': '0.0000'},
#   '2008-01-31': {'1. open': '2.9298',
#    '2. high': '2.9402',
#    '3. low': '1.8998',
#    '4. close': '2.0850',
#    '5. adjusted close': '7.4941',
#    '6. volume': '114710561',
#    '7. dividend amount': '0.0000'},
#   '2007-12-31': {'1. open': '3.0000',
#    '2. high': '3.1098',
#    '3. low': '2.7399',
#    '4. close': '2.9199',
#    '5. adjusted close': '10.4953',
#    '6. volume': '90177785',
#    '7. dividend amount': '0.0000'},
#   '2007-11-30': {'1. open': '3.3502',
#    '2. high': '3.3502',
#    '3. low': '2.9402',
#    '4. close': '2.9902',
#    '5. adjusted close': '10.7469',
#    '6. volume': '105807704',
#    '7. dividend amount': '0.1493'},
#   '2007-10-31': {'1. open': '2.9199',
#    '2. high': '3.5400',
#    '3. low': '2.8502',
#    '4. close': '3.3403',
#    '5. adjusted close': '11.8648',
#    '6. volume': '132518694',
#    '7. dividend amount': '0.0000'},
#   '2007-09-28': {'1. open': '3.4802',
#    '2. high': '3.5301',
#    '3. low': '2.6801',
#    '4. close': '2.9100',
#    '5. adjusted close': '10.3373',
#    '6. volume': '138399349',
#    '7. dividend amount': '0.0000'},
#   '2007-08-31': {'1. open': '3.6799',
#    '2. high': '3.9801',
#    '3. low': '3.1899',
#    '4. close': '3.4303',
#    '5. adjusted close': '12.1845',
#    '6. volume': '118116010',
#    '7. dividend amount': '0.0000'},
#   '2007-07-31': {'1. open': '4.1502',
#    '2. high': '4.2002',
#    '3. low': '3.4599',
#    '4. close': '3.7601',
#    '5. adjusted close': '13.3567',
#    '6. volume': '197967760',
#    '7. dividend amount': '0.0000'},
#   '2007-06-29': {'1. open': '3.7903',
#    '2. high': '4.3000',
#    '3. low': '3.4500',
#    '4. close': '4.1398',
#    '5. adjusted close': '14.7066',
#    '6. volume': '224584434',
#    '7. dividend amount': '0.1937'},
#   '2007-05-31': {'1. open': '3.0999',
#    '2. high': '3.7798',
#    '3. low': '2.9199',
#    '4. close': '3.7699',
#    '5. adjusted close': '13.2122',
#    '6. volume': '192041929',
#    '7. dividend amount': '0.0000'},
#   '2007-04-30': {'1. open': '2.7103',
#    '2. high': '3.1202',
#    '3. low': '2.7103',
#    '4. close': '3.0900',
#    '5. adjusted close': '10.8291',
#    '6. volume': '137528877',
#    '7. dividend amount': '0.0000'},
#   '2007-03-30': {'1. open': '2.7701',
#    '2. high': '2.8200',
#    '3. low': '2.5698',
#    '4. close': '2.7103',
#    '5. adjusted close': '9.4974',
#    '6. volume': '99260403',
#    '7. dividend amount': '0.0000'},
#   '2007-02-28': {'1. open': '2.8502',
#    '2. high': '2.9402',
#    '3. low': '2.7498',
#    '4. close': '2.7602',
#    '5. adjusted close': '9.6726',
#    '6. volume': '64764572',
#    '7. dividend amount': '0.0000'},
#   '2007-01-31': {'1. open': '2.7997',
#    '2. high': '2.9199',
#    '3. low': '2.7202',
#    '4. close': '2.8398',
#    '5. adjusted close': '9.9530',
#    '6. volume': '81261537',
#    '7. dividend amount': '0.0000'},
#   '2006-12-29': {'1. open': '2.5599',
#    '2. high': '2.8799',
#    '3. low': '2.5402',
#    '4. close': '2.7997',
#    '5. adjusted close': '9.8128',
#    '6. volume': '74872992',
#    '7. dividend amount': '0.0000'},
#   '2006-11-30': {'1. open': '2.5501',
#    '2. high': '2.6401',
#    '3. low': '2.5402',
#    '4. close': '2.5599',
#    '5. adjusted close': '8.9717',
#    '6. volume': '47676389',
#    '7. dividend amount': '0.1493'},
#   '2006-10-31': {'1. open': '2.4601',
#    '2. high': '2.5803',
#    '3. low': '2.4397',
#    '4. close': '2.5501',
#    '5. adjusted close': '8.8095',
#    '6. volume': '67089056',
#    '7. dividend amount': '0.0000'},
#   '2006-09-29': {'1. open': '2.4101',
#    '2. high': '2.4699',
#    '3. low': '2.3898',
#    '4. close': '2.4502',
#    '5. adjusted close': '8.4640',
#    '6. volume': '54863322',
#    '7. dividend amount': '0.0000'},
#   '2006-08-31': {'1. open': '2.2400',
#    '2. high': '2.4200',
#    '3. low': '2.2203',
#    '4. close': '2.4003',
#    '5. adjusted close': '8.2913',
#    '6. volume': '37811453',
#    '7. dividend amount': '0.0000'},
#   '2006-07-31': {'1. open': '2.2203',
#    '2. high': '2.2801',
#    '3. low': '2.1901',
#    '4. close': '2.2499',
#    '5. adjusted close': '7.7730',
#    '6. volume': '43031017',
#    '7. dividend amount': '0.0000'},
#   '2006-06-30': {'1. open': '2.2499',
#    '2. high': '2.3103',
#    '3. low': '2.1401',
#    '4. close': '2.2203',
#    '5. adjusted close': '7.6694',
#    '6. volume': '58597926',
#    '7. dividend amount': '0.0000'},
#   '2006-05-31': {'1. open': '2.4101',
#    '2. high': '2.4299',
#    '3. low': '2.1802',
#    '4. close': '2.2598',
#    '5. adjusted close': '7.8076',
#    '6. volume': '104974944',
#    '7. dividend amount': '0.0000'},
#   '2006-04-28': {'1. open': '2.6302',
#    '2. high': '2.6401',
#    '3. low': '2.4003',
#    '4. close': '2.4200',
#    '5. adjusted close': '8.3603',
#    '6. volume': '52187807',
#    '7. dividend amount': '0.1493'},
#   '2006-03-31': {'1. open': '2.5001',
#    '2. high': '2.7997',
#    '3. low': '2.3701',
#    '4. close': '2.6302',
#    '5. adjusted close': '8.9580',
#    '6. volume': '129293434',
#    '7. dividend amount': '0.0000'},
#   '2006-02-28': {'1. open': '2.4003',
#    '2. high': '2.5599',
#    '3. low': '2.4003',
#    '4. close': '2.4903',
#    '5. adjusted close': '8.4812',
#    '6. volume': '57330011',
#    '7. dividend amount': '0.0000'},
#   '2006-01-31': {'1. open': '2.3300',
#    '2. high': '2.4798',
#    '3. low': '2.2998',
#    '4. close': '2.4101',
#    '5. adjusted close': '8.2087',
#    '6. volume': '108258223',
#    '7. dividend amount': '0.0000'},
#   '2005-12-30': {'1. open': '2.1001',
#    '2. high': '2.3498',
#    '3. low': '2.0502',
#    '4. close': '2.3300',
#    '5. adjusted close': '7.9362',
#    '6. volume': '77786402',
#    '7. dividend amount': '0.0000'},
#   '2005-11-30': {'1. open': '2.1100',
#    '2. high': '2.1802',
#    '3. low': '2.1001',
#    '4. close': '2.1100',
#    '5. adjusted close': '7.1868',
#    '6. volume': '57266657',
#    '7. dividend amount': '0.0000'},
#   '2005-10-31': {'1. open': '2.3103',
#    '2. high': '2.3898',
#    '3. low': '2.0200',
#    '4. close': '2.1100',
#    '5. adjusted close': '7.1868',
#    '6. volume': '76971280',
#    '7. dividend amount': '0.1331'},
#   '2005-09-30': {'1. open': '2.1901',
#    '2. high': '2.3103',
#    '3. low': '2.1802',
#    '4. close': '2.3103',
#    '5. adjusted close': '7.7547',
#    '6. volume': '76402657',
#    '7. dividend amount': '0.0000'},
#   '2005-08-31': {'1. open': '2.1100',
#    '2. high': '2.2098',
#    '3. low': '2.0798',
#    '4. close': '2.1802',
#    '5. adjusted close': '7.3183',
#    '6. volume': '48863059',
#    '7. dividend amount': '0.0000'},
#   '2005-07-29': {'1. open': '2.1198',
#    '2. high': '2.1303',
#    '3. low': '2.0502',
#    '4. close': '2.1100',
#    '5. adjusted close': '7.0833',
#    '6. volume': '31012572',
#    '7. dividend amount': '0.0000'},
#   '2005-06-30': {'1. open': '2.1001',
#    '2. high': '2.1401',
#    '3. low': '2.0298',
#    '4. close': '2.1198',
#    '5. adjusted close': '7.1168',
#    '6. volume': '34542762',
#    '7. dividend amount': '0.0000'},
#   '2005-05-31': {'1. open': '2.0902',
#    '2. high': '2.1401',
#    '3. low': '2.0798',
#    '4. close': '2.1001',
#    '5. adjusted close': '7.0497',
#    '6. volume': '43967714',
#    '7. dividend amount': '0.0000'},
#   '2005-04-29': {'1. open': '2.0798',
#    '2. high': '2.1500',
#    '3. low': '2.0502',
#    '4. close': '2.0798',
#    '5. adjusted close': '6.9826',
#    '6. volume': '25893934',
#    '7. dividend amount': '0.1412'},
#   '2005-03-31': {'1. open': '2.1001',
#    '2. high': '2.1901',
#    '3. low': '2.0699',
#    '4. close': '2.1001',
#    '5. adjusted close': '6.9322',
#    '6. volume': '59038597',
#    '7. dividend amount': '0.0000'},
#   '2005-02-28': {'1. open': '2.1198',
#    '2. high': '2.1599',
#    '3. low': '2.0798',
#    '4. close': '2.1100',
#    '5. adjusted close': '6.9652',
#    '6. volume': '43777814',
#    '7. dividend amount': '0.0000'}}}

# %%
time_series = data["Monthly Adjusted Time Series"]
df = pd.DataFrame.from_dict(time_series, orient = "index")
df.index = pd.to_datetime(df.index)
df.index.name = "date"
df = df[["1. open", "2. high", "3. low", "4. close", "5. adjusted close", "6. volume", "7. dividend amount"]]
df.columns = ["open", "high", "low", "close", "adjusted_close", "volume", "dividend_amount"]
df = df.sort_index() # ordena por data

# %%
time_series
# Out:
# {'2025-02-07': {'1. open': '0.4919',
#   '2. high': '0.5088',
#   '3. low': '0.4911',
#   '4. close': '0.5008',
#   '5. adjusted close': '0.5008',
#   '6. volume': '247712741',
#   '7. dividend amount': '0.0000'},
#  '2025-01-31': {'1. open': '0.4665',
#   '2. high': '0.5226',
#   '3. low': '0.4435',
#   '4. close': '0.5054',
#   '5. adjusted close': '0.5054',
#   '6. volume': '1591983949',
#   '7. dividend amount': '0.0000'},
#  '2024-12-31': {'1. open': '0.4448',
#   '2. high': '0.4674',
#   '3. low': '0.4325',
#   '4. close': '0.4647',
#   '5. adjusted close': '0.4647',
#   '6. volume': '960959277',
#   '7. dividend amount': '0.0000'},
#  '2024-11-29': {'1. open': '0.4632',
#   '2. high': '0.4665',
#   '3. low': '0.4335',
#   '4. close': '0.4478',
#   '5. adjusted close': '0.4478',
#   '6. volume': '1110365383',
#   '7. dividend amount': '0.0000'},
#  '2024-10-31': {'1. open': '0.4060',
#   '2. high': '0.4679',
#   '3. low': '0.3853',
#   '4. close': '0.4634',
#   '5. adjusted close': '0.4634',
#   '6. volume': '1465600221',
#   '7. dividend amount': '0.0000'},
#  '2024-09-30': {'1. open': '0.4189',
#   '2. high': '0.4242',
#   '3. low': '0.3990',
#   '4. close': '0.4054',
#   '5. adjusted close': '0.4054',
#   '6. volume': '1144027755',
#   '7. dividend amount': '0.0000'},
#  '2024-08-30': {'1. open': '0.3934',
#   '2. high': '0.4170',
#   '3. low': '0.3400',
#   '4. close': '0.4159',
#   '5. adjusted close': '0.4159',
#   '6. volume': '1405588344',
#   '7. dividend amount': '0.0000'},
#  '2024-07-31': {'1. open': '0.3425',
#   '2. high': '0.4024',
#   '3. low': '0.3423',
#   '4. close': '0.3898',
#   '5. adjusted close': '0.3898',
#   '6. volume': '1457378829',
#   '7. dividend amount': '0.0000'},
#  '2024-06-28': {'1. open': '0.3780',
#   '2. high': '0.3796',
#   '3. low': '0.3163',
#   '4. close': '0.3366',
#   '5. adjusted close': '0.3366',
#   '6. volume': '1442604119',
#   '7. dividend amount': '0.0170'},
#  '2024-05-31': {'1. open': '0.3302',
#   '2. high': '0.3740',
#   '3. low': '0.3249',
#   '4. close': '0.3717',
#   '5. adjusted close': '0.3528',
#   '6. volume': '1847345971',
#   '7. dividend amount': '0.0000'},
#  '2024-04-30': {'1. open': '0.3120',
#   '2. high': '0.3319',
#   '3. low': '0.2882',
#   '4. close': '0.3286',
#   '5. adjusted close': '0.3119',
#   '6. volume': '1637814003',
#   '7. dividend amount': '0.0000'},
#  '2024-03-28': {'1. open': '0.2697',
#   '2. high': '0.3137',
#   '3. low': '0.2581',
#   '4. close': '0.3126',
#   '5. adjusted close': '0.2967',
#   '6. volume': '1415965416',
#   '7. dividend amount': '0.0000'},
#  '2024-02-29': {'1. open': '0.2660',
#   '2. high': '0.2848',
#   '3. low': '0.2533',
#   '4. close': '0.2670',
#   '5. adjusted close': '0.2534',
#   '6. volume': '1164828485',
#   '7. dividend amount': '0.0000'},
#  '2024-01-31': {'1. open': '0.2759',
#   '2. high': '0.3150',
#   '3. low': '0.2628',
#   '4. close': '0.2701',
#   '5. adjusted close': '0.2563',
#   '6. volume': '1760691249',
#   '7. dividend amount': '0.0000'},
#  '2023-12-29': {'1. open': '0.3087',
#   '2. high': '0.3343',
#   '3. low': '0.2651',
#   '4. close': '0.2744',
#   '5. adjusted close': '0.2604',
#   '6. volume': '2182095029',
#   '7. dividend amount': '0.0000'},
#  '2023-11-30': {'1. open': '0.2920',
#   '2. high': '0.3105',
#   '3. low': '0.2747',
#   '4. close': '0.3082',
#   '5. adjusted close': '0.2925',
#   '6. volume': '1935268892',
#   '7. dividend amount': '0.0000'},
#  '2023-10-31': {'1. open': '0.2614',
#   '2. high': '0.2945',
#   '3. low': '0.2558',
#   '4. close': '0.2896',
#   '5. adjusted close': '0.2748',
#   '6. volume': '1688609087',
#   '7. dividend amount': '0.0000'},
#  '2023-09-29': {'1. open': '0.2578',
#   '2. high': '0.2682',
#   '3. low': '0.2380',
#   '4. close': '0.2604',
#   '5. adjusted close': '0.2471',
#   '6. volume': '1370997389',
#   '7. dividend amount': '0.0000'},
#  '2023-08-31': {'1. open': '0.2483',
#   '2. high': '0.2608',
#   '3. low': '0.2350',
#   '4. close': '0.2574',
#   '5. adjusted close': '0.2443',
#   '6. volume': '1064070483',
#   '7. dividend amount': '0.0000'},
#  '2023-07-31': {'1. open': '0.2200',
#   '2. high': '0.2685',
#   '3. low': '0.2164',
#   '4. close': '0.2483',
#   '5. adjusted close': '0.2357',
#   '6. volume': '1472832105',
#   '7. dividend amount': '0.0000'},
#  '2023-06-30': {'1. open': '0.2070',
#   '2. high': '0.2262',
#   '3. low': '0.2011',
#   '4. close': '0.2196',
#   '5. adjusted close': '0.2084',
#   '6. volume': '1003213260',
#   '7. dividend amount': '0.0000'},
#  '2023-05-31': {'1. open': '0.2342',
#   '2. high': '0.2369',
#   '3. low': '0.2048',
#   '4. close': '0.2056',
#   '5. adjusted close': '0.1951',
#   '6. volume': '1414338949',
#   '7. dividend amount': '0.0000'},
#  '2023-04-28': {'1. open': '0.2027',
#   '2. high': '0.2414',
#   '3. low': '0.2010',
#   '4. close': '0.2330',
#   '5. adjusted close': '0.2211',
#   '6. volume': '1669206668',
#   '7. dividend amount': '0.0000'},
#  '2023-03-31': {'1. open': '0.2300',
#   '2. high': '0.2322',
#   '3. low': '0.1694',
#   '4. close': '0.2040',
#   '5. adjusted close': '0.1936',
#   '6. volume': '2672050356',
#   '7. dividend amount': '0.0000'},
#  '2023-02-28': {'1. open': '0.1960',
#   '2. high': '0.2344',
#   '3. low': '0.1914',
#   '4. close': '0.2282',
#   '5. adjusted close': '0.2166',
#   '6. volume': '2296614328',
#   '7. dividend amount': '0.0000'},
#  '2023-01-31': {'1. open': '0.1480',
#   '2. high': '0.1970',
#   '3. low': '0.1476',
#   '4. close': '0.1953',
#   '5. adjusted close': '0.1854',
#   '6. volume': '2581721996',
#   '7. dividend amount': '0.0000'},
#  '2022-12-30': {'1. open': '0.1539',
#   '2. high': '0.1539',
#   '3. low': '0.1397',
#   '4. close': '0.1464',
#   '5. adjusted close': '0.1389',
#   '6. volume': '1087718428',
#   '7. dividend amount': '0.0000'},
#  '2022-11-30': {'1. open': '0.1470',
#   '2. high': '0.1599',
#   '3. low': '0.1422',
#   '4. close': '0.1527',
#   '5. adjusted close': '0.1449',
#   '6. volume': '1811178991',
#   '7. dividend amount': '0.0000'},
#  '2022-10-31': {'1. open': '0.1208',
#   '2. high': '0.1466',
#   '3. low': '0.1184',
#   '4. close': '0.1444',
#   '5. adjusted close': '0.1370',
#   '6. volume': '1638890802',
#   '7. dividend amount': '0.0000'},
#  '2022-09-30': {'1. open': '0.1438',
#   '2. high': '0.1585',
#   '3. low': '0.1205',
#   '4. close': '0.1218',
#   '5. adjusted close': '0.1156',
#   '6. volume': '1788110626',
#   '7. dividend amount': '0.0000'},
#  '2022-08-31': {'1. open': '0.1440',
#   '2. high': '0.1579',
#   '3. low': '0.1390',
#   '4. close': '0.1452',
#   '5. adjusted close': '0.1378',
#   '6. volume': '1094158962',
#   '7. dividend amount': '0.0000'},
#  '2022-07-29': {'1. open': '0.1647',
#   '2. high': '0.1676',
#   '3. low': '0.1330',
#   '4. close': '0.1445',
#   '5. adjusted close': '0.1371',
#   '6. volume': '1932200885',
#   '7. dividend amount': '0.0000'},
#  '2022-06-30': {'1. open': '0.1920',
#   '2. high': '0.1995',
#   '3. low': '0.1628',
#   '4. close': '0.1650',
#   '5. adjusted close': '0.1566',
#   '6. volume': '2183997844',
#   '7. dividend amount': '0.0009'},
#  '2022-05-31': {'1. open': '0.1470',
#   '2. high': '0.1983',
#   '3. low': '0.1405',
#   '4. close': '0.1918',
#   '5. adjusted close': '0.1812',
#   '6. volume': '2446855406',
#   '7. dividend amount': '0.0000'},
#  '2022-04-29': {'1. open': '0.1731',
#   '2. high': '0.1774',
#   '3. low': '0.1461',
#   '4. close': '0.1480',
#   '5. adjusted close': '0.1398',
#   '6. volume': '1854853379',
#   '7. dividend amount': '0.0000'},
#  '2022-03-31': {'1. open': '0.1653',
#   '2. high': '0.1775',
#   '3. low': '0.1200',
#   '4. close': '0.1731',
#   '5. adjusted close': '0.1635',
#   '6. volume': '3811265641',
#   '7. dividend amount': '0.0000'},
#  '2022-02-28': {'1. open': '0.1524',
#   '2. high': '0.2030',
#   '3. low': '0.1506',
#   '4. close': '0.1651',
#   '5. adjusted close': '0.1560',
#   '6. volume': '2367357121',
#   '7. dividend amount': '0.0000'},
#  '2022-01-31': {'1. open': '0.1420',
#   '2. high': '0.1742',
#   '3. low': '0.1418',
#   '4. close': '0.1505',
#   '5. adjusted close': '0.1422',
#   '6. volume': '1700129950',
#   '7. dividend amount': '0.0000'},
#  '2021-12-31': {'1. open': '0.1446',
#   '2. high': '0.1503',
#   '3. low': '0.1271',
#   '4. close': '0.1409',
#   '5. adjusted close': '0.1331',
#   '6. volume': '1072792607',
#   '7. dividend amount': '0.0000'},
#  '2021-11-30': {'1. open': '0.1565',
#   '2. high': '0.1628',
#   '3. low': '0.1400',
#   '4. close': '0.1435',
#   '5. adjusted close': '0.1356',
#   '6. volume': '1390418477',
#   '7. dividend amount': '0.0000'},
#  '2021-10-29': {'1. open': '0.1536',
#   '2. high': '0.1749',
#   '3. low': '0.1510',
#   '4. close': '0.1561',
#   '5. adjusted close': '0.1475',
#   '6. volume': '1789544724',
#   '7. dividend amount': '0.0000'},
#  '2021-09-30': {'1. open': '0.1320',
#   '2. high': '0.1580',
#   '3. low': '0.1224',
#   '4. close': '0.1567',
#   '5. adjusted close': '0.1480',
#   '6. volume': '1360235858',
#   '7. dividend amount': '0.0000'},
#  '2021-08-31': {'1. open': '0.1210',
#   '2. high': '0.1347',
#   '3. low': '0.1192',
#   '4. close': '0.1312',
#   '5. adjusted close': '0.1239',
#   '6. volume': '797888631',
#   '7. dividend amount': '0.0000'},
#  '2021-07-30': {'1. open': '0.1350',
#   '2. high': '0.1389',
#   '3. low': '0.1162',
#   '4. close': '0.1200',
#   '5. adjusted close': '0.1134',
#   '6. volume': '917190683',
#   '7. dividend amount': '0.0000'},
#  '2021-06-30': {'1. open': '0.1600',
#   '2. high': '0.1645',
#   '3. low': '0.1321',
#   '4. close': '0.1350',
#   '5. adjusted close': '0.1275',
#   '6. volume': '823689472',
#   '7. dividend amount': '0.0000'},
#  '2021-05-31': {'1. open': '0.1241',
#   '2. high': '0.1738',
#   '3. low': '0.1228',
#   '4. close': '0.1591',
#   '5. adjusted close': '0.1503',
#   '6. volume': '1548186922',
#   '7. dividend amount': '0.0000'},
#  '2021-04-30': {'1. open': '0.1162',
#   '2. high': '0.1284',
#   '3. low': '0.1110',
#   '4. close': '0.1245',
#   '5. adjusted close': '0.1176',
#   '6. volume': '1018353469',
#   '7. dividend amount': '0.0000'},
#  '2021-03-31': {'1. open': '0.1191',
#   '2. high': '0.1225',
#   '3. low': '0.1125',
#   '4. close': '0.1161',
#   '5. adjusted close': '0.1097',
#   '6. volume': '1107569187',
#   '7. dividend amount': '0.0000'},
#  '2021-02-26': {'1. open': '0.1154',
#   '2. high': '0.1287',
#   '3. low': '0.1134',
#   '4. close': '0.1172',
#   '5. adjusted close': '0.1107',
#   '6. volume': '1041416698',
#   '7. dividend amount': '0.0000'},
#  '2021-01-29': {'1. open': '0.1243',
#   '2. high': '0.1494',
#   '3. low': '0.1088',
#   '4. close': '0.1142',
#   '5. adjusted close': '0.1079',
#   '6. volume': '1121892247',
#   '7. dividend amount': '0.0000'},
#  '2020-12-31': {'1. open': '0.1192',
#   '2. high': '0.1305',
#   '3. low': '0.1130',
#   '4. close': '0.1232',
#   '5. adjusted close': '0.1164',
#   '6. volume': '912170318',
#   '7. dividend amount': '0.0000'},
#  '2020-11-30': {'1. open': '0.0754',
#   '2. high': '0.1233',
#   '3. low': '0.0735',
#   '4. close': '0.1185',
#   '5. adjusted close': '0.1119',
#   '6. volume': '1390024267',
#   '7. dividend amount': '0.0000'},
#  '2020-10-30': {'1. open': '0.0807',
#   '2. high': '0.0837',
#   '3. low': '0.0681',
#   '4. close': '0.0754',
#   '5. adjusted close': '0.0712',
#   '6. volume': '693233952',
#   '7. dividend amount': '0.0000'},
#  '2020-09-30': {'1. open': '0.0987',
#   '2. high': '0.0989',
#   '3. low': '0.0785',
#   '4. close': '0.0803',
#   '5. adjusted close': '0.0759',
#   '6. volume': '880649390',
#   '7. dividend amount': '0.0000'},
#  '2020-08-31': {'1. open': '0.0982',
#   '2. high': '0.1078',
#   '3. low': '0.0962',
#   '4. close': '0.0987',
#   '5. adjusted close': '0.0932',
#   '6. volume': '519434924',
#   '7. dividend amount': '0.0000'},
#  '2020-07-31': {'1. open': '0.1068',
#   '2. high': '0.1124',
#   '3. low': '0.0967',
#   '4. close': '0.0982',
#   '5. adjusted close': '0.0928',
#   '6. volume': '947865556',
#   '7. dividend amount': '0.0000'},
#  '2020-06-30': {'1. open': '0.0998',
#   '2. high': '0.1220',
#   '3. low': '0.0991',
#   '4. close': '0.1070',
#   '5. adjusted close': '0.1011',
#   '6. volume': '1750697749',
#   '7. dividend amount': '0.0000'},
#  '2020-05-29': {'1. open': '0.0995',
#   '2. high': '0.1037',
#   '3. low': '0.0846',
#   '4. close': '0.0985',
#   '5. adjusted close': '0.0930',
#   '6. volume': '1472555272',
#   '7. dividend amount': '0.0000'},
#  '2020-04-30': {'1. open': '0.1012',
#   '2. high': '0.1080',
#   '3. low': '0.0890',
#   '4. close': '0.1020',
#   '5. adjusted close': '0.0963',
#   '6. volume': '1711254946',
#   '7. dividend amount': '0.0000'},
#  '2020-03-31': {'1. open': '0.1668',
#   '2. high': '0.1673',
#   '3. low': '0.0997',
#   '4. close': '0.1025',
#   '5. adjusted close': '0.0968',
#   '6. volume': '2120737194',
#   '7. dividend amount': '0.0000'},
#  '2020-02-28': {'1. open': '0.1920',
#   '2. high': '0.2027',
#   '3. low': '0.1613',
#   '4. close': '0.1625',
#   '5. adjusted close': '0.1535',
#   '6. volume': '709772257',
#   '7. dividend amount': '0.0000'},
#  '2020-01-31': {'1. open': '0.2034',
#   '2. high': '0.2135',
#   '3. low': '0.1814',
#   '4. close': '0.1917',
#   '5. adjusted close': '0.1811',
#   '6. volume': '690415644',
#   '7. dividend amount': '0.0000'},
#  '2019-12-31': {'1. open': '0.1962',
#   '2. high': '0.2071',
#   '3. low': '0.1882',
#   '4. close': '0.2028',
#   '5. adjusted close': '0.1916',
#   '6. volume': '597186795',
#   '7. dividend amount': '0.0000'},
#  '2019-11-29': {'1. open': '0.2033',
#   '2. high': '0.2235',
#   '3. low': '0.1960',
#   '4. close': '0.1960',
#   '5. adjusted close': '0.1851',
#   '6. volume': '777597492',
#   '7. dividend amount': '0.0000'},
#  '2019-10-31': {'1. open': '0.1907',
#   '2. high': '0.2095',
#   '3. low': '0.1810',
#   '4. close': '0.2030',
#   '5. adjusted close': '0.1918',
#   '6. volume': '989377715',
#   '7. dividend amount': '0.0000'},
#  '2019-09-30': {'1. open': '0.1936',
#   '2. high': '0.2154',
#   '3. low': '0.1750',
#   '4. close': '0.1906',
#   '5. adjusted close': '0.1800',
#   '6. volume': '1421721393',
#   '7. dividend amount': '0.0000'},
#  '2019-08-30': {'1. open': '0.2310',
#   '2. high': '0.2331',
#   '3. low': '0.1860',
#   '4. close': '0.1932',
#   '5. adjusted close': '0.1825',
#   '6. volume': '1266685059',
#   '7. dividend amount': '0.0000'},
#  '2019-07-31': {'1. open': '0.2744',
#   '2. high': '0.2892',
#   '3. low': '0.2312',
#   '4. close': '0.2312',
#   '5. adjusted close': '0.2184',
#   '6. volume': '1100736743',
#   '7. dividend amount': '0.0000'},
#  '2019-06-28': {'1. open': '0.2511',
#   '2. high': '0.2724',
#   '3. low': '0.2454',
#   '4. close': '0.2719',
#   '5. adjusted close': '0.2568',
#   '6. volume': '917790386',
#   '7. dividend amount': '0.0020'},
#  '2019-05-31': {'1. open': '0.2489',
#   '2. high': '0.2592',
#   '3. low': '0.2401',
#   '4. close': '0.2520',
#   '5. adjusted close': '0.2361',
#   '6. volume': '856951357',
#   '7. dividend amount': '0.0000'},
#  '2019-04-30': {'1. open': '0.2318',
#   '2. high': '0.2518',
#   '3. low': '0.2293',
#   '4. close': '0.2501',
#   '5. adjusted close': '0.2344',
#   '6. volume': '761425027',
#   '7. dividend amount': '0.0000'},
#  '2019-03-29': {'1. open': '0.2420',
#   '2. high': '0.2465',
#   '3. low': '0.2165',
#   '4. close': '0.2303',
#   '5. adjusted close': '0.2158',
#   '6. volume': '923569827',
#   '7. dividend amount': '0.0000'},
#  '2019-02-28': {'1. open': '0.2408',
#   '2. high': '0.2425',
#   '3. low': '0.2250',
#   '4. close': '0.2410',
#   '5. adjusted close': '0.2258',
#   '6. volume': '803954126',
#   '7. dividend amount': '0.0000'},
#  '2019-01-31': {'1. open': '0.2294',
#   '2. high': '0.2493',
#   '3. low': '0.2240',
#   '4. close': '0.2410',
#   '5. adjusted close': '0.2258',
#   '6. volume': '725198701',
#   '7. dividend amount': '0.0000'},
#  '2018-12-31': {'1. open': '0.2510',
#   '2. high': '0.2555',
#   '3. low': '0.2162',
#   '4. close': '0.2295',
#   '5. adjusted close': '0.2151',
#   '6. volume': '642696277',
#   '7. dividend amount': '0.0000'},
#  '2018-11-30': {'1. open': '0.2382',
#   '2. high': '0.2582',
#   '3. low': '0.2341',
#   '4. close': '0.2481',
#   '5. adjusted close': '0.2325',
#   '6. volume': '775943428',
#   '7. dividend amount': '0.0000'},
#  '2018-10-31': {'1. open': '0.2560',
#   '2. high': '0.2569',
#   '3. low': '0.2148',
#   '4. close': '0.2382',
#   '5. adjusted close': '0.2232',
#   '6. volume': '957359334',
#   '7. dividend amount': '0.0000'},
#  '2018-09-28': {'1. open': '0.2510',
#   '2. high': '0.2664',
#   '3. low': '0.2354',
#   '4. close': '0.2550',
#   '5. adjusted close': '0.2390',
#   '6. volume': '803642149',
#   '7. dividend amount': '0.0000'},
#  '2018-08-31': {'1. open': '0.2692',
#   '2. high': '0.2699',
#   '3. low': '0.2496',
#   '4. close': '0.2508',
#   '5. adjusted close': '0.2350',
#   '6. volume': '601488177',
#   '7. dividend amount': '0.0000'},
#  '2018-07-31': {'1. open': '0.2550',
#   '2. high': '0.2735',
#   '3. low': '0.2501',
#   '4. close': '0.2684',
#   '5. adjusted close': '0.2515',
#   '6. volume': '633078413',
#   '7. dividend amount': '0.0000'},
#  '2018-06-29': {'1. open': '0.2561',
#   '2. high': '0.2791',
#   '3. low': '0.2551',
#   '4. close': '0.2574',
#   '5. adjusted close': '0.2412',
#   '6. volume': '1203604420',
#   '7. dividend amount': '0.0000'},
#  '2018-05-31': {'1. open': '0.2782',
#   '2. high': '0.3042',
#   '3. low': '0.2316',
#   '4. close': '0.2512',
#   '5. adjusted close': '0.2354',
#   '6. volume': '1452309758',
#   '7. dividend amount': '0.0000'},
#  '2018-04-30': {'1. open': '0.2700',
#   '2. high': '0.2941',
#   '3. low': '0.2599',
#   '4. close': '0.2781',
#   '5. adjusted close': '0.2606',
#   '6. volume': '690500707',
#   '7. dividend amount': '0.0000'},
#  '2018-03-29': {'1. open': '0.2940',
#   '2. high': '0.3175',
#   '3. low': '0.2677',
#   '4. close': '0.2720',
#   '5. adjusted close': '0.2549',
#   '6. volume': '1536572067',
#   '7. dividend amount': '0.0000'},
#  '2018-02-28': {'1. open': '0.3220',
#   '2. high': '0.3280',
#   '3. low': '0.2811',
#   '4. close': '0.2950',
#   '5. adjusted close': '0.2764',
#   '6. volume': '1108839819',
#   '7. dividend amount': '0.0000'},
#  '2018-01-31': {'1. open': '0.2728',
#   '2. high': '0.3360',
#   '3. low': '0.2728',
#   '4. close': '0.3221',
#   '5. adjusted close': '0.3018',
#   '6. volume': '1569530871',
#   '7. dividend amount': '0.0000'},
#  '2017-12-29': {'1. open': '0.2571',
#   '2. high': '0.2735',
#   '3. low': '0.2555',
#   '4. close': '0.2720',
#   '5. adjusted close': '0.2549',
#   '6. volume': '1052887203',
#   '7. dividend amount': '0.0000'},
#  '2017-11-30': {'1. open': '0.2578',
#   '2. high': '0.2580',
#   '3. low': '0.2402',
#   '4. close': '0.2575',
#   '5. adjusted close': '0.2413',
#   '6. volume': '975488551',
#   '7. dividend amount': '0.0000'},
#  '2017-10-31': {'1. open': '0.2465',
#   '2. high': '0.2600',
#   '3. low': '0.2375',
#   '4. close': '0.2565',
#   '5. adjusted close': '0.2404',
#   '6. volume': '1641638842',
#   '7. dividend amount': '0.0000'},
#  '2017-09-29': {'1. open': '0.2245',
#   '2. high': '0.2475',
#   '3. low': '0.1855',
#   '4. close': '0.2453',
#   '5. adjusted close': '0.2299',
#   '6. volume': '1994871534',
#   '7. dividend amount': '0.0000'},
#  '2017-08-31': {'1. open': '0.2417',
#   '2. high': '0.2460',
#   '3. low': '0.2115',
#   '4. close': '0.2234',
#   '5. adjusted close': '0.2093',
#   '6. volume': '1067300100',
#   '7. dividend amount': '0.0000'},
#  '2017-07-31': {'1. open': '0.2377',
#   '2. high': '0.2603',
#   '3. low': '0.2341',
#   '4. close': '0.2414',
#   '5. adjusted close': '0.2262',
#   '6. volume': '1440043021',
#   '7. dividend amount': '0.0000'},
#  '2017-06-30': {'1. open': '0.2300',
#   '2. high': '0.2456',
#   '3. low': '0.2181',
#   '4. close': '0.2357',
#   '5. adjusted close': '0.2209',
#   '6. volume': '1949190116',
#   '7. dividend amount': '0.0000'},
#  '2017-05-31': {'1. open': '0.2053',
#   '2. high': '0.2375',
#   '3. low': '0.2016',
#   '4. close': '0.2300',
#   '5. adjusted close': '0.2155',
#   '6. volume': '2101142908',
#   '7. dividend amount': '0.0000'},
#  '2017-04-28': {'1. open': '0.1935',
#   '2. high': '0.2096',
#   '3. low': '0.1732',
#   '4. close': '0.2048',
#   '5. adjusted close': '0.1919',
#   '6. volume': '1361256151',
#   '7. dividend amount': '0.0000'},
#  '2017-03-31': {'1. open': '0.1520',
#   '2. high': '0.2000',
#   '3. low': '0.1491',
#   '4. close': '0.1961',
#   '5. adjusted close': '0.1838',
#   '6. volume': '2318054136',
#   '7. dividend amount': '0.0000'},
#  '2017-02-28': {'1. open': '0.1586',
#   '2. high': '0.1835',
#   '3. low': '0.1327',
#   '4. close': '0.1507',
#   '5. adjusted close': '0.1412',
#   '6. volume': '1571024040',
#   '7. dividend amount': '0.0000'},
#  '2017-01-31': {'1. open': '1.0680',
#   '2. high': '1.1077',
#   '3. low': '0.1409',
#   '4. close': '0.1564',
#   '5. adjusted close': '0.1466',
#   '6. volume': '888231271',
#   '7. dividend amount': '0.0000'},
#  '2016-12-30': {'1. open': '1.1775',
#   '2. high': '1.3930',
#   '3. low': '1.0200',
#   '4. close': '1.0710',
#   '5. adjusted close': '0.1729',
#   '6. volume': '569750983',
#   '7. dividend amount': '0.0000'},
#  '2016-11-30': {'1. open': '1.2169',
#   '2. high': '1.3240',
#   '3. low': '1.0701',
#   '4. close': '1.1800',
#   '5. adjusted close': '0.1904',
#   '6. volume': '286271968',
#   '7. dividend amount': '0.0000'},
#  '2016-10-31': {'1. open': '0.0157',
#   '2. high': '1.3597',
#   '3. low': '0.0151',
#   '4. close': '1.2130',
#   '5. adjusted close': '0.1958',
#   '6. volume': '246570549',
#   '7. dividend amount': '0.0000'},
#  '2016-09-30': {'1. open': '0.0180',
#   '2. high': '0.0192',
#   '3. low': '0.0139',
#   '4. close': '0.0157',
#   '5. adjusted close': '0.1864',
#   '6. volume': '446614456',
#   '7. dividend amount': '0.0000'},
#  '2016-08-31': {'1. open': '0.0215',
#   '2. high': '0.0226',
#   '3. low': '0.0174',
#   '4. close': '0.0180',
#   '5. adjusted close': '0.2179',
#   '6. volume': '305915624',
#   '7. dividend amount': '0.0000'},
#  '2016-07-29': {'1. open': '0.0186',
#   '2. high': '0.0221',
#   '3. low': '0.0174',
#   '4. close': '0.0203',
#   '5. adjusted close': '0.2445',
#   '6. volume': '394342592',
#   '7. dividend amount': '0.0000'},
#  '2016-06-30': {'1. open': '0.0308',
#   '2. high': '0.0308',
#   '3. low': '0.0151',
#   '4. close': '0.0180',
#   '5. adjusted close': '0.2203',
#   '6. volume': '1065115970',
#   '7. dividend amount': '0.0000'},
#  '2016-05-31': {'1. open': '0.0389',
#   '2. high': '0.0401',
#   '3. low': '0.0302',
#   '4. close': '0.0308',
#   '5. adjusted close': '0.3704',
#   '6. volume': '601445969',
#   '7. dividend amount': '0.0000'},
#  '2016-04-29': {'1. open': '0.0354',
#   '2. high': '0.0412',
#   '3. low': '0.0308',
#   '4. close': '0.0389',
#   '5. adjusted close': '0.4685',
#   '6. volume': '626150161',
#   '7. dividend amount': '0.0000'},
#  '2016-03-31': {'1. open': '0.0343',
#   '2. high': '0.0476',
#   '3. low': '0.0343',
#   '4. close': '0.0354',
#   '5. adjusted close': '0.4321',
#   '6. volume': '729412815',
#   '7. dividend amount': '0.0000'},
#  '2016-02-29': {'1. open': '0.0389',
#   '2. high': '0.0401',
#   '3. low': '0.0308',
#   '4. close': '0.0343',
#   '5. adjusted close': '0.4164',
#   '6. volume': '520271341',
#   '7. dividend amount': '0.0000'},
#  '2016-01-29': {'1. open': '0.0482',
#   '2. high': '0.0517',
#   '3. low': '0.0314',
#   '4. close': '0.0389',
#   '5. adjusted close': '0.4709',
#   '6. volume': '480029367',
#   '7. dividend amount': '0.0000'},
#  '2015-12-31': {'1. open': '0.0511',
#   '2. high': '0.0528',
#   '3. low': '0.0459',
#   '4. close': '0.0488',
#   '5. adjusted close': '0.5919',
#   '6. volume': '324156868',
#   '7. dividend amount': '0.0000'},
#  '2015-11-30': {'1. open': '0.0523',
#   '2. high': '0.0581',
#   '3. low': '0.0441',
#   '4. close': '0.0505',
#   '5. adjusted close': '0.6125',
#   '6. volume': '466689514',
#   '7. dividend amount': '0.0000'},
#  '2015-10-30': {'1. open': '0.0447',
#   '2. high': '0.0656',
#   '3. low': '0.0441',
#   '4. close': '0.0523',
#   '5. adjusted close': '0.6331',
#   '6. volume': '643139155',
#   '7. dividend amount': '0.0000'},
#  '2015-09-30': {'1. open': '0.0627',
#   '2. high': '0.0627',
#   '3. low': '0.0406',
#   '4. close': '0.0435',
#   '5. adjusted close': '0.5266',
#   '6. volume': '444923388',
#   '7. dividend amount': '0.0000'},
#  '2015-08-31': {'1. open': '0.0703',
#   '2. high': '0.0714',
#   '3. low': '0.0540',
#   '4. close': '0.0633',
#   '5. adjusted close': '0.7626',
#   '6. volume': '379032950',
#   '7. dividend amount': '0.0000'},
#  '2015-07-31': {'1. open': '0.0784',
#   '2. high': '0.0848',
#   '3. low': '0.0691',
#   '4. close': '0.0703',
#   '5. adjusted close': '0.8473',
#   '6. volume': '465347884',
#   '7. dividend amount': '0.0000'},
#  '2015-06-30': {'1. open': '0.0854',
#   '2. high': '0.0900',
#   '3. low': '0.0737',
#   '4. close': '0.0778',
#   '5. adjusted close': '0.9442',
#   '6. volume': '460216258',
#   '7. dividend amount': '0.0000'},
#  '2015-05-29': {'1. open': '0.0900',
#   '2. high': '0.0941',
#   '3. low': '0.0842',
#   '4. close': '0.0854',
#   '5. adjusted close': '1.0313',
#   '6. volume': '270518408',
#   '7. dividend amount': '0.0000'},
#  '2015-04-30': {'1. open': '0.0952',
#   '2. high': '0.0964',
#   '3. low': '0.0807',
#   '4. close': '0.0888',
#   '5. adjusted close': '1.0785',
#   '6. volume': '337363020',
#   '7. dividend amount': '0.0000'},
#  '2015-03-31': {'1. open': '0.0836',
#   '2. high': '0.0987',
#   '3. low': '0.0824',
#   '4. close': '0.0958',
#   '5. adjusted close': '1.1584',
#   '6. volume': '484505960',
#   '7. dividend amount': '0.0000'},
#  '2015-02-27': {'1. open': '0.0633',
#   '2. high': '0.0848',
#   '3. low': '0.0615',
#   '4. close': '0.0830',
#   '5. adjusted close': '1.0071',
#   '6. volume': '453633566',
#   '7. dividend amount': '0.0000'},
#  '2015-01-30': {'1. open': '0.0674',
#   '2. high': '0.0749',
#   '3. low': '0.0586',
#   '4. close': '0.0633',
#   '5. adjusted close': '0.7626',
#   '6. volume': '520018220',
#   '7. dividend amount': '0.0000'},
#  '2014-12-31': {'1. open': '0.0819',
#   '2. high': '0.0859',
#   '3. low': '0.0644',
#   '4. close': '0.0656',
#   '5. adjusted close': '0.7953',
#   '6. volume': '435651100',
#   '7. dividend amount': '0.0000'},
#  '2014-11-28': {'1. open': '0.0888',
#   '2. high': '0.0900',
#   '3. low': '0.0708',
#   '4. close': '0.0830',
#   '5. adjusted close': '1.0047',
#   '6. volume': '437246436',
#   '7. dividend amount': '0.0000'},
#  '2014-10-31': {'1. open': '0.1033',
#   '2. high': '0.1068',
#   '3. low': '0.0766',
#   '4. close': '0.0900',
#   '5. adjusted close': '1.0894',
#   '6. volume': '642884680',
#   '7. dividend amount': '0.0000'},
#  '2014-09-30': {'1. open': '0.1039',
#   '2. high': '0.1138',
#   '3. low': '0.0993',
#   '4. close': '0.1033',
#   '5. adjusted close': '1.2540',
#   '6. volume': '479994049',
#   '7. dividend amount': '0.0000'},
#  '2014-08-29': {'1. open': '0.1092',
#   '2. high': '0.1109',
#   '3. low': '0.0703',
#   '4. close': '0.1033',
#   '5. adjusted close': '1.2528',
#   '6. volume': '514096040',
#   '7. dividend amount': '0.0000'},
#  '2014-07-31': {'1. open': '0.1150',
#   '2. high': '0.1405',
#   '3. low': '0.0958',
#   '4. close': '0.1074',
#   '5. adjusted close': '1.2976',
#   '6. volume': '743895673',
#   '7. dividend amount': '0.0000'},
#  '2014-06-30': {'1. open': '0.1922',
#   '2. high': '0.2084',
#   '3. low': '0.1440',
#   '4. close': '0.1910',
#   '5. adjusted close': '1.3410',
#   '6. volume': '486355214',
#   '7. dividend amount': '0.0000'},
#  '2014-05-30': {'1. open': '0.2212',
#   '2. high': '0.2305',
#   '3. low': '0.1579',
#   '4. close': '0.1916',
#   '5. adjusted close': '1.3466',
#   '6. volume': '510341989',
#   '7. dividend amount': '0.0000'},
#  '2014-04-30': {'1. open': '0.2288',
#   '2. high': '0.2392',
#   '3. low': '0.2021',
#   '4. close': '0.2189',
#   '5. adjusted close': '1.5384',
#   '6. volume': '364321649',
#   '7. dividend amount': '0.0000'},
#  '2014-03-31': {'1. open': '0.1939',
#   '2. high': '0.2375',
#   '3. low': '0.1881',
#   '4. close': '0.2270',
#   '5. adjusted close': '1.5946',
#   '6. volume': '550453685',
#   '7. dividend amount': '0.0000'},
#  '2014-02-28': {'1. open': '0.1655',
#   '2. high': '0.1997',
#   '3. low': '0.1573',
#   '4. close': '0.1974',
#   '5. adjusted close': '1.3852',
#   '6. volume': '342679209',
#   '7. dividend amount': '0.0000'},
#  '2014-01-31': {'1. open': '0.1695',
#   '2. high': '0.1945',
#   '3. low': '0.1620',
#   '4. close': '0.1661',
#   '5. adjusted close': '1.1661',
#   '6. volume': '571309761',
#   '7. dividend amount': '0.0000'},
#  '2013-12-31': {'1. open': '0.1312',
#   '2. high': '0.1870',
#   '3. low': '0.1295',
#   '4. close': '0.1666',
#   '5. adjusted close': '1.1689',
#   '6. volume': '475481038',
#   '7. dividend amount': '0.0000'},
#  '2013-11-29': {'1. open': '0.1097',
#   '2. high': '0.1353',
#   '3. low': '0.1092',
#   '4. close': '0.1301',
#   '5. adjusted close': '0.9146',
#   '6. volume': '332030543',
#   '7. dividend amount': '0.0000'},
#  '2013-10-31': {'1. open': '0.0952',
#   '2. high': '0.1126',
#   '3. low': '0.0952',
#   '4. close': '0.1103',
#   '5. adjusted close': '0.7741',
#   '6. volume': '369535062',
#   '7. dividend amount': '0.0000'},
#  '2013-09-30': {'1. open': '0.0970',
#   '2. high': '0.0999',
#   '3. low': '0.0929',
#   '4. close': '0.0958',
#   '5. adjusted close': '0.6744',
#   '6. volume': '160769326',
#   '7. dividend amount': '0.0000'},
#  '2013-08-30': {'1. open': '0.0952',
#   '2. high': '0.1097',
#   '3. low': '0.0941',
#   '4. close': '0.0958',
#   '5. adjusted close': '0.6744',
#   '6. volume': '271000934',
#   '7. dividend amount': '0.0000'},
#  '2013-07-31': {'1. open': '0.0958',
#   '2. high': '0.0999',
#   '3. low': '0.0732',
#   '4. close': '0.0941',
#   '5. adjusted close': '0.6603',
#   '6. volume': '400346068',
#   '7. dividend amount': '0.0000'},
#  '2013-06-28': {'1. open': '0.1051',
#   '2. high': '0.1068',
#   '3. low': '0.0848',
#   '4. close': '0.0958',
#   '5. adjusted close': '0.6744',
#   '6. volume': '228653143',
#   '7. dividend amount': '0.0000'},
#  '2013-05-31': {'1. open': '0.1051',
#   '2. high': '0.1109',
#   '3. low': '0.0999',
#   '4. close': '0.1068',
#   '5. adjusted close': '0.7516',
#   '6. volume': '329801875',
#   '7. dividend amount': '0.0000'},
#  '2013-04-30': {'1. open': '0.0952',
#   '2. high': '0.1068',
#   '3. low': '0.0801',
#   '4. close': '0.1051',
#   '5. adjusted close': '0.7376',
#   '6. volume': '462851310',
#   '7. dividend amount': '0.0000'},
#  '2013-03-28': {'1. open': '0.1092',
#   '2. high': '0.1132',
#   '3. low': '0.0912',
#   '4. close': '0.0952',
#   '5. adjusted close': '0.6673',
#   '6. volume': '363806507',
#   '7. dividend amount': '0.0000'},
#  '2013-02-28': {'1. open': '0.0993',
#   '2. high': '0.1173',
#   '3. low': '0.0958',
#   '4. close': '0.1092',
#   '5. adjusted close': '0.7657',
#   '6. volume': '474455334',
#   '7. dividend amount': '0.0000'},
#  '2013-01-31': {'1. open': '0.0772',
#   '2. high': '0.1202',
#   '3. low': '0.0761',
#   '4. close': '0.0993',
#   '5. adjusted close': '0.6954',
#   '6. volume': '700129293',
#   '7. dividend amount': '0.0000'},
#  '2012-12-31': {'1. open': '0.0708',
#   '2. high': '0.0790',
#   '3. low': '0.0703',
#   '4. close': '0.0749',
#   '5. adjusted close': '0.5268',
#   '6. volume': '228890141',
#   '7. dividend amount': '0.0000'},
#  '2012-11-30': {'1. open': '0.0703',
#   '2. high': '0.0732',
#   '3. low': '0.0662',
#   '4. close': '0.0703',
#   '5. adjusted close': '0.4917',
#   '6. volume': '205420895',
#   '7. dividend amount': '0.0000'},
#  '2012-10-31': {'1. open': '0.0650',
#   '2. high': '0.0848',
#   '3. low': '0.0650',
#   '4. close': '0.0703',
#   '5. adjusted close': '0.4917',
#   '6. volume': '456114175',
#   '7. dividend amount': '0.0000'},
#  '2012-09-28': {'1. open': '0.0883',
#   '2. high': '0.0952',
#   '3. low': '0.0557',
#   '4. close': '0.0639',
#   '5. adjusted close': '0.4496',
#   '6. volume': '264753143',
#   '7. dividend amount': '0.0000'},
#  '2012-08-31': {'1. open': '0.0929',
#   '2. high': '0.0993',
#   '3. low': '0.0871',
#   '4. close': '0.0871',
#   '5. adjusted close': '0.3939',
#   '6. volume': '88479635',
#   '7. dividend amount': '0.0000'},
#  '2012-07-31': {'1. open': '0.0999',
#   '2. high': '0.1028',
#   '3. low': '0.0900',
#   '4. close': '0.0941',
#   '5. adjusted close': '0.4256',
#   '6. volume': '65819796',
#   '7. dividend amount': '0.0000'},
#  '2012-06-29': {'1. open': '0.1022',
#   '2. high': '0.1039',
#   '3. low': '0.0732',
#   '4. close': '0.0981',
#   '5. adjusted close': '0.4437',
#   '6. volume': '168476114',
#   '7. dividend amount': '0.0000'},
#  '2012-05-31': {'1. open': '0.1051',
#   '2. high': '0.1179',
#   '3. low': '0.0958',
#   '4. close': '0.1022',
#   '5. adjusted close': '0.4618',
#   '6. volume': '154524180',
#   '7. dividend amount': '0.0000'},
#  '2012-04-30': {'1. open': '0.1388',
#   '2. high': '0.1411',
#   '3. low': '0.1028',
#   '4. close': '0.1063',
#   '5. adjusted close': '0.4799',
#   '6. volume': '192278275',
#   '7. dividend amount': '0.0000'},
#  '2012-03-30': {'1. open': '0.1701',
#   '2. high': '0.1719',
#   '3. low': '0.1370',
#   '4. close': '0.1388',
#   '5. adjusted close': '0.6293',
#   '6. volume': '290358295',
#   '7. dividend amount': '0.0000'},
#  '2012-02-29': {'1. open': '0.1353',
#   '2. high': '0.2189',
#   '3. low': '0.1353',
#   '4. close': '0.1701',
#   '5. adjusted close': '0.7697',
#   '6. volume': '621534870',
#   '7. dividend amount': '0.0000'},
#  '2012-01-31': {'1. open': '0.1382',
#   '2. high': '0.1533',
#   '3. low': '0.1208',
#   '4. close': '0.1353',
#   '5. adjusted close': '0.6112',
#   '6. volume': '407825751',
#   '7. dividend amount': '0.0000'},
#  '2011-12-30': {'1. open': '0.1289',
#   '2. high': '0.1440',
#   '3. low': '0.1039',
#   '4. close': '0.1359',
#   '5. adjusted close': '0.6157',
#   '6. volume': '284274733',
#   '7. dividend amount': '0.0000'},
#  '2011-11-30': {'1. open': '0.1521',
#   '2. high': '0.1678',
#   '3. low': '0.0970',
#   '4. close': '0.1272',
#   '5. adjusted close': '0.5750',
#   '6. volume': '621197415',
#   '7. dividend amount': '0.0000'},
#  '2011-10-31': {'1. open': '0.1910',
#   '2. high': '0.1910',
#   '3. low': '0.1510',
#   '4. close': '0.1550',
#   '5. adjusted close': '0.7018',
#   '6. volume': '187402727',
#   '7. dividend amount': '0.0000'},
#  '2011-09-30': {'1. open': '0.2531',
#   '2. high': '0.2537',
#   '3. low': '0.1701',
#   '4. close': '0.1951',
#   '5. adjusted close': '0.8829',
#   '6. volume': '221974961',
#   '7. dividend amount': '0.0000'},
#  '2011-08-31': {'1. open': '0.3269',
#   '2. high': '0.3310',
#   '3. low': '0.2433',
#   '4. close': '0.2531',
#   '5. adjusted close': '1.1454',
#   '6. volume': '203793207',
#   '7. dividend amount': '0.0000'},
#  '2011-07-29': {'1. open': '0.4128',
#   '2. high': '0.4140',
#   '3. low': '0.2920',
#   '4. close': '0.3222',
#   '5. adjusted close': '1.4578',
#   '6. volume': '252683167',
#   '7. dividend amount': '0.0000'},
#  '2011-06-30': {'1. open': '0.4709',
#   '2. high': '0.4918',
#   '3. low': '0.3791',
#   '4. close': '0.4099',
#   '5. adjusted close': '1.8562',
#   '6. volume': '171825428',
#   '7. dividend amount': '0.0000'},
#  '2011-05-31': {'1. open': '0.5400',
#   '2. high': '0.5748',
#   '3. low': '0.4569',
#   '4. close': '0.4807',
#   '5. adjusted close': '2.1777',
#   '6. volume': '90595278',
#   '7. dividend amount': '0.0000'},
#  '2011-04-29': {'1. open': '0.5760',
#   '2. high': '0.6247',
#   '3. low': '0.5231',
#   '4. close': '0.5388',
#   '5. adjusted close': '2.3644',
#   '6. volume': '68733655',
#   '7. dividend amount': '0.0000'},
#  '2011-03-31': {'1. open': '0.6468',
#   '2. high': '0.6573',
#   '3. low': '0.5719',
#   '4. close': '0.5760',
#   '5. adjusted close': '2.4202',
#   '6. volume': '107975133',
#   '7. dividend amount': '0.0000'},
#  '2011-02-28': {'1. open': '0.5911',
#   '2. high': '0.6480',
#   '3. low': '0.5858',
#   '4. close': '0.6462',
#   '5. adjusted close': '2.7144',
#   '6. volume': '114187972',
#   '7. dividend amount': '0.0000'},
#  '2011-01-31': {'1. open': '0.5899',
#   '2. high': '0.6300',
#   '3. low': '0.5051',
#   '4. close': '0.5870',
#   '5. adjusted close': '2.4665',
#   '6. volume': '117176728',
#   '7. dividend amount': '0.0000'},
#  '2010-12-31': {'1. open': '0.5899',
#   '2. high': '0.6369',
#   '3. low': '0.5818',
#   '4. close': '0.5818',
#   '5. adjusted close': '2.4455',
#   '6. volume': '69198896',
#   '7. dividend amount': '0.0000'},
#  '2010-11-30': {'1. open': '0.6631',
#   '2. high': '0.6683',
#   '3. low': '0.5858',
#   '4. close': '0.5882',
#   '5. adjusted close': '2.4707',
#   '6. volume': '132796405',
#   '7. dividend amount': '0.0000'},
#  '2010-10-29': {'1. open': '0.6398',
#   '2. high': '0.6770',
#   '3. low': '0.6288',
#   '4. close': '0.6538',
#   '5. adjusted close': '2.7480',
#   '6. volume': '101721192',
#   '7. dividend amount': '0.0000'},
#  '2010-09-30': {'1. open': '0.6323',
#   '2. high': '0.6619',
#   '3. low': '0.6067',
#   '4. close': '0.6393',
#   '5. adjusted close': '2.6850',
#   '6. volume': '121107707',
#   '7. dividend amount': '0.0000'},
#  '2010-08-31': {'1. open': '0.6660',
#   '2. high': '0.7043',
#   '3. low': '0.6021',
#   '4. close': '0.6300',
#   '5. adjusted close': '2.6471',
#   '6. volume': '108724957',
#   '7. dividend amount': '0.0000'},
#  '2010-07-30': {'1. open': '0.6108',
#   '2. high': '0.7043',
#   '3. low': '0.6009',
#   '4. close': '0.6642',
#   '5. adjusted close': '2.7900',
#   '6. volume': '150467516',
#   '7. dividend amount': '0.0000'},
#  '2010-06-30': {'1. open': '0.6410',
#   '2. high': '0.6799',
#   '3. low': '0.5858',
#   '4. close': '0.6201',
#   '5. adjusted close': '2.6051',
#   '6. volume': '126721509',
#   '7. dividend amount': '0.0000'},
#  '2010-05-31': {'1. open': '0.7101',
#   '2. high': '0.7351',
#   '3. low': '0.5998',
#   '4. close': '0.6439',
#   '5. adjusted close': '2.7060',
#   '6. volume': '195928008',
#   '7. dividend amount': '0.0000'},
#  '2010-04-30': {'1. open': '0.8227',
#   '2. high': '0.8529',
#   '3. low': '0.5551',
#   '4. close': '0.7031',
#   '5. adjusted close': '2.9539',
#   '6. volume': '162849155',
#   '7. dividend amount': '0.0852'},
#  '2010-03-31': {'1. open': '0.7502',
#   '2. high': '0.8570',
#   '3. low': '0.7368',
#   '4. close': '0.8239',
#   '5. adjusted close': '3.3820',
#   '6. volume': '94613806',
#   '7. dividend amount': '0.0000'},
#  '2010-02-26': {'1. open': '0.7891',
#   '2. high': '0.8140',
#   '3. low': '0.6758',
#   '4. close': '0.7438',
#   '5. adjusted close': '3.0536',
#   '6. volume': '140931407',
#   '7. dividend amount': '0.0000'},
#  '2010-01-29': {'1. open': '0.8500',
#   '2. high': '0.9330',
#   '3. low': '0.7629',
#   '4. close': '0.7850',
#   '5. adjusted close': '3.2219',
#   '6. volume': '118689797',
#   '7. dividend amount': '0.0000'},
#  '2009-12-31': {'1. open': '0.8872',
#   '2. high': '0.8959',
#   '3. low': '0.7612',
#   '4. close': '0.8448',
#   '5. adjusted close': '3.4682',
#   '6. volume': '83040849',
#   '7. dividend amount': '0.0000'},
#  '2009-11-30': {'1. open': '0.9690',
#   '2. high': '0.9847',
#   '3. low': '0.8732',
#   '4. close': '0.8820',
#   '5. adjusted close': '3.6200',
#   '6. volume': '70837745',
#   '7. dividend amount': '0.0000'},
#  '2009-10-30': {'1. open': '1.0138',
#   '2. high': '1.0747',
#   '3. low': '0.9127',
#   '4. close': '0.9702',
#   '5. adjusted close': '3.9812',
#   '6. volume': '98835109',
#   '7. dividend amount': '0.0000'},
#  '2009-09-30': {'1. open': '0.9162',
#   '2. high': '1.0463',
#   '3. low': '0.8802',
#   '4. close': '1.0109',
#   '5. adjusted close': '4.1495',
#   '6. volume': '103163183',
#   '7. dividend amount': '0.0000'},
#  '2009-08-31': {'1. open': '0.7531',
#   '2. high': '0.9638',
#   '3. low': '0.7531',
#   '4. close': '0.9127',
#   '5. adjusted close': '3.7473',
#   '6. volume': '117204536',
#   '7. dividend amount': '0.0000'},
#  '2009-07-31': {'1. open': '0.7200',
#   '2. high': '0.7751',
#   '3. low': '0.7049',
#   '4. close': '0.7507',
#   '5. adjusted close': '3.0824',
#   '6. volume': '47520568',
#   '7. dividend amount': '0.0000'},
#  '2009-06-30': {'1. open': '0.7687',
#   '2. high': '0.7931',
#   '3. low': '0.6962',
#   '4. close': '0.7240',
#   '5. adjusted close': '2.9715',
#   '6. volume': '60188070',
#   '7. dividend amount': '0.0000'},
#  '2009-05-29': {'1. open': '0.7322',
#   '2. high': '0.8552',
#   '3. low': '0.6950',
#   '4. close': '0.7560',
#   '5. adjusted close': '3.1029',
#   '6. volume': '103286578',
#   '7. dividend amount': '0.0000'},
#  '2009-04-30': {'1. open': '0.6201',
#   '2. high': '0.7653',
#   '3. low': '0.5998',
#   '4. close': '0.7101',
#   '5. adjusted close': '2.9141',
#   '6. volume': '116728156',
#   '7. dividend amount': '0.0762'},
#  '2009-03-31': {'1. open': '0.6108',
#   '2. high': '0.6549',
#   '3. low': '0.5562',
#   '4. close': '0.6178',
#   '5. adjusted close': '2.4685',
#   '6. volume': '70584767',
#   '7. dividend amount': '0.0000'},
#  '2009-02-27': {'1. open': '0.7931',
#   '2. high': '0.8001',
#   '3. low': '0.5568',
#   '4. close': '0.6398',
#   '5. adjusted close': '2.5563',
#   '6. volume': '48455763',
#   '7. dividend amount': '0.0000'},
#  '2009-01-30': {'1. open': '0.8140',
#   '2. high': '0.8721',
#   '3. low': '0.7362',
#   '4. close': '0.8001',
#   '5. adjusted close': '3.1954',
#   '6. volume': '34726108',
#   '7. dividend amount': '0.0000'},
#  '2008-12-31': {'1. open': '0.8198',
#   '2. high': '0.8709',
#   '3. low': '0.7612',
#   '4. close': '0.8152',
#   '5. adjusted close': '3.2553',
#   '6. volume': '31347568',
#   '7. dividend amount': '0.0000'},
#  '2008-11-28': {'1. open': '0.9098',
#   '2. high': '0.9278',
#   '3. low': '0.6851',
#   '4. close': '0.7989',
#   '5. adjusted close': '3.1914',
#   '6. volume': '47785128',
#   '7. dividend amount': '0.0000'},
#  '2008-10-31': {'1. open': '1.1577',
#   '2. high': '1.1618',
#   '3. low': '0.8448',
#   '4. close': '0.9127',
#   '5. adjusted close': '3.6468',
#   '6. volume': '74451114',
#   '7. dividend amount': '0.0000'},
#  '2008-09-30': {'1. open': '1.1688',
#   '2. high': '1.3598',
#   '3. low': '1.0701',
#   '4. close': '1.1421',
#   '5. adjusted close': '4.5615',
#   '6. volume': '109792955',
#   '7. dividend amount': '0.0000'},
#  '2008-08-29': {'1. open': '1.1252',
#   '2. high': '1.1903',
#   '3. low': '1.1049',
#   '4. close': '1.1798',
#   '5. adjusted close': '4.7132',
#   '6. volume': '58856581',
#   '7. dividend amount': '0.0000'},
#  '2008-07-31': {'1. open': '1.3749',
#   '2. high': '1.3801',
#   '3. low': '1.0248',
#   '4. close': '1.1450',
#   '5. adjusted close': '4.5734',
#   '6. volume': '137732193',
#   '7. dividend amount': '0.0000'},
#  '2008-06-30': {'1. open': '1.6298',
#   '2. high': '1.6698',
#   '3. low': '1.3552',
#   '4. close': '1.3749',
#   '5. adjusted close': '5.4921',
#   '6. volume': '81871507',
#   '7. dividend amount': '0.0000'},
#  '2008-05-30': {'1. open': '1.8400',
#   '2. high': '1.8649',
#   '3. low': '1.6100',
#   '4. close': '1.6350',
#   '5. adjusted close': '6.5306',
#   '6. volume': '64541004',
#   '7. dividend amount': '0.0000'},
#  '2008-04-30': {'1. open': '2.0502',
#   '2. high': '2.2400',
#   '3. low': '1.7848',
#   '4. close': '1.8051',
#   '5. adjusted close': '7.2097',
#   '6. volume': '111050037',
#   '7. dividend amount': '0.0000'},
#  '2008-03-31': {'1. open': '1.8853',
#   '2. high': '2.0902',
#   '3. low': '1.7053',
#   '4. close': '2.0600',
#   '5. adjusted close': '7.4042',
#   '6. volume': '66191329',
#   '7. dividend amount': '0.0000'},
#  '2008-02-29': {'1. open': '2.1001',
#   '2. high': '2.1047',
#   '3. low': '1.6751',
#   '4. close': '1.9102',
#   '5. adjusted close': '6.8651',
#   '6. volume': '72515359',
#   '7. dividend amount': '0.0000'},
#  '2008-01-31': {'1. open': '2.9298',
#   '2. high': '2.9402',
#   '3. low': '1.8998',
#   '4. close': '2.0850',
#   '5. adjusted close': '7.4941',
#   '6. volume': '114710561',
#   '7. dividend amount': '0.0000'},
#  '2007-12-31': {'1. open': '3.0000',
#   '2. high': '3.1098',
#   '3. low': '2.7399',
#   '4. close': '2.9199',
#   '5. adjusted close': '10.4953',
#   '6. volume': '90177785',
#   '7. dividend amount': '0.0000'},
#  '2007-11-30': {'1. open': '3.3502',
#   '2. high': '3.3502',
#   '3. low': '2.9402',
#   '4. close': '2.9902',
#   '5. adjusted close': '10.7469',
#   '6. volume': '105807704',
#   '7. dividend amount': '0.1493'},
#  '2007-10-31': {'1. open': '2.9199',
#   '2. high': '3.5400',
#   '3. low': '2.8502',
#   '4. close': '3.3403',
#   '5. adjusted close': '11.8648',
#   '6. volume': '132518694',
#   '7. dividend amount': '0.0000'},
#  '2007-09-28': {'1. open': '3.4802',
#   '2. high': '3.5301',
#   '3. low': '2.6801',
#   '4. close': '2.9100',
#   '5. adjusted close': '10.3373',
#   '6. volume': '138399349',
#   '7. dividend amount': '0.0000'},
#  '2007-08-31': {'1. open': '3.6799',
#   '2. high': '3.9801',
#   '3. low': '3.1899',
#   '4. close': '3.4303',
#   '5. adjusted close': '12.1845',
#   '6. volume': '118116010',
#   '7. dividend amount': '0.0000'},
#  '2007-07-31': {'1. open': '4.1502',
#   '2. high': '4.2002',
#   '3. low': '3.4599',
#   '4. close': '3.7601',
#   '5. adjusted close': '13.3567',
#   '6. volume': '197967760',
#   '7. dividend amount': '0.0000'},
#  '2007-06-29': {'1. open': '3.7903',
#   '2. high': '4.3000',
#   '3. low': '3.4500',
#   '4. close': '4.1398',
#   '5. adjusted close': '14.7066',
#   '6. volume': '224584434',
#   '7. dividend amount': '0.1937'},
#  '2007-05-31': {'1. open': '3.0999',
#   '2. high': '3.7798',
#   '3. low': '2.9199',
#   '4. close': '3.7699',
#   '5. adjusted close': '13.2122',
#   '6. volume': '192041929',
#   '7. dividend amount': '0.0000'},
#  '2007-04-30': {'1. open': '2.7103',
#   '2. high': '3.1202',
#   '3. low': '2.7103',
#   '4. close': '3.0900',
#   '5. adjusted close': '10.8291',
#   '6. volume': '137528877',
#   '7. dividend amount': '0.0000'},
#  '2007-03-30': {'1. open': '2.7701',
#   '2. high': '2.8200',
#   '3. low': '2.5698',
#   '4. close': '2.7103',
#   '5. adjusted close': '9.4974',
#   '6. volume': '99260403',
#   '7. dividend amount': '0.0000'},
#  '2007-02-28': {'1. open': '2.8502',
#   '2. high': '2.9402',
#   '3. low': '2.7498',
#   '4. close': '2.7602',
#   '5. adjusted close': '9.6726',
#   '6. volume': '64764572',
#   '7. dividend amount': '0.0000'},
#  '2007-01-31': {'1. open': '2.7997',
#   '2. high': '2.9199',
#   '3. low': '2.7202',
#   '4. close': '2.8398',
#   '5. adjusted close': '9.9530',
#   '6. volume': '81261537',
#   '7. dividend amount': '0.0000'},
#  '2006-12-29': {'1. open': '2.5599',
#   '2. high': '2.8799',
#   '3. low': '2.5402',
#   '4. close': '2.7997',
#   '5. adjusted close': '9.8128',
#   '6. volume': '74872992',
#   '7. dividend amount': '0.0000'},
#  '2006-11-30': {'1. open': '2.5501',
#   '2. high': '2.6401',
#   '3. low': '2.5402',
#   '4. close': '2.5599',
#   '5. adjusted close': '8.9717',
#   '6. volume': '47676389',
#   '7. dividend amount': '0.1493'},
#  '2006-10-31': {'1. open': '2.4601',
#   '2. high': '2.5803',
#   '3. low': '2.4397',
#   '4. close': '2.5501',
#   '5. adjusted close': '8.8095',
#   '6. volume': '67089056',
#   '7. dividend amount': '0.0000'},
#  '2006-09-29': {'1. open': '2.4101',
#   '2. high': '2.4699',
#   '3. low': '2.3898',
#   '4. close': '2.4502',
#   '5. adjusted close': '8.4640',
#   '6. volume': '54863322',
#   '7. dividend amount': '0.0000'},
#  '2006-08-31': {'1. open': '2.2400',
#   '2. high': '2.4200',
#   '3. low': '2.2203',
#   '4. close': '2.4003',
#   '5. adjusted close': '8.2913',
#   '6. volume': '37811453',
#   '7. dividend amount': '0.0000'},
#  '2006-07-31': {'1. open': '2.2203',
#   '2. high': '2.2801',
#   '3. low': '2.1901',
#   '4. close': '2.2499',
#   '5. adjusted close': '7.7730',
#   '6. volume': '43031017',
#   '7. dividend amount': '0.0000'},
#  '2006-06-30': {'1. open': '2.2499',
#   '2. high': '2.3103',
#   '3. low': '2.1401',
#   '4. close': '2.2203',
#   '5. adjusted close': '7.6694',
#   '6. volume': '58597926',
#   '7. dividend amount': '0.0000'},
#  '2006-05-31': {'1. open': '2.4101',
#   '2. high': '2.4299',
#   '3. low': '2.1802',
#   '4. close': '2.2598',
#   '5. adjusted close': '7.8076',
#   '6. volume': '104974944',
#   '7. dividend amount': '0.0000'},
#  '2006-04-28': {'1. open': '2.6302',
#   '2. high': '2.6401',
#   '3. low': '2.4003',
#   '4. close': '2.4200',
#   '5. adjusted close': '8.3603',
#   '6. volume': '52187807',
#   '7. dividend amount': '0.1493'},
#  '2006-03-31': {'1. open': '2.5001',
#   '2. high': '2.7997',
#   '3. low': '2.3701',
#   '4. close': '2.6302',
#   '5. adjusted close': '8.9580',
#   '6. volume': '129293434',
#   '7. dividend amount': '0.0000'},
#  '2006-02-28': {'1. open': '2.4003',
#   '2. high': '2.5599',
#   '3. low': '2.4003',
#   '4. close': '2.4903',
#   '5. adjusted close': '8.4812',
#   '6. volume': '57330011',
#   '7. dividend amount': '0.0000'},
#  '2006-01-31': {'1. open': '2.3300',
#   '2. high': '2.4798',
#   '3. low': '2.2998',
#   '4. close': '2.4101',
#   '5. adjusted close': '8.2087',
#   '6. volume': '108258223',
#   '7. dividend amount': '0.0000'},
#  '2005-12-30': {'1. open': '2.1001',
#   '2. high': '2.3498',
#   '3. low': '2.0502',
#   '4. close': '2.3300',
#   '5. adjusted close': '7.9362',
#   '6. volume': '77786402',
#   '7. dividend amount': '0.0000'},
#  '2005-11-30': {'1. open': '2.1100',
#   '2. high': '2.1802',
#   '3. low': '2.1001',
#   '4. close': '2.1100',
#   '5. adjusted close': '7.1868',
#   '6. volume': '57266657',
#   '7. dividend amount': '0.0000'},
#  '2005-10-31': {'1. open': '2.3103',
#   '2. high': '2.3898',
#   '3. low': '2.0200',
#   '4. close': '2.1100',
#   '5. adjusted close': '7.1868',
#   '6. volume': '76971280',
#   '7. dividend amount': '0.1331'},
#  '2005-09-30': {'1. open': '2.1901',
#   '2. high': '2.3103',
#   '3. low': '2.1802',
#   '4. close': '2.3103',
#   '5. adjusted close': '7.7547',
#   '6. volume': '76402657',
#   '7. dividend amount': '0.0000'},
#  '2005-08-31': {'1. open': '2.1100',
#   '2. high': '2.2098',
#   '3. low': '2.0798',
#   '4. close': '2.1802',
#   '5. adjusted close': '7.3183',
#   '6. volume': '48863059',
#   '7. dividend amount': '0.0000'},
#  '2005-07-29': {'1. open': '2.1198',
#   '2. high': '2.1303',
#   '3. low': '2.0502',
#   '4. close': '2.1100',
#   '5. adjusted close': '7.0833',
#   '6. volume': '31012572',
#   '7. dividend amount': '0.0000'},
#  '2005-06-30': {'1. open': '2.1001',
#   '2. high': '2.1401',
#   '3. low': '2.0298',
#   '4. close': '2.1198',
#   '5. adjusted close': '7.1168',
#   '6. volume': '34542762',
#   '7. dividend amount': '0.0000'},
#  '2005-05-31': {'1. open': '2.0902',
#   '2. high': '2.1401',
#   '3. low': '2.0798',
#   '4. close': '2.1001',
#   '5. adjusted close': '7.0497',
#   '6. volume': '43967714',
#   '7. dividend amount': '0.0000'},
#  '2005-04-29': {'1. open': '2.0798',
#   '2. high': '2.1500',
#   '3. low': '2.0502',
#   '4. close': '2.0798',
#   '5. adjusted close': '6.9826',
#   '6. volume': '25893934',
#   '7. dividend amount': '0.1412'},
#  '2005-03-31': {'1. open': '2.1001',
#   '2. high': '2.1901',
#   '3. low': '2.0699',
#   '4. close': '2.1001',
#   '5. adjusted close': '6.9322',
#   '6. volume': '59038597',
#   '7. dividend amount': '0.0000'},
#  '2005-02-28': {'1. open': '2.1198',
#   '2. high': '2.1599',
#   '3. low': '2.0798',
#   '4. close': '2.1100',
#   '5. adjusted close': '6.9652',
#   '6. volume': '43777814',
#   '7. dividend amount': '0.0000'}}

# %%
df
# Out:
#               open    high     low   close adjusted_close      volume  \
# date
# 2005-02-28  2.1198  2.1599  2.0798  2.1100         6.9652    43777814
# 2005-03-31  2.1001  2.1901  2.0699  2.1001         6.9322    59038597
# 2005-04-29  2.0798  2.1500  2.0502  2.0798         6.9826    25893934
# 2005-05-31  2.0902  2.1401  2.0798  2.1001         7.0497    43967714
# 2005-06-30  2.1001  2.1401  2.0298  2.1198         7.1168    34542762
# ...            ...     ...     ...     ...            ...         ...
# 2024-10-31  0.4060  0.4679  0.3853  0.4634         0.4634  1465600221
# 2024-11-29  0.4632  0.4665  0.4335  0.4478         0.4478  1110365383
# 2024-12-31  0.4448  0.4674  0.4325  0.4647         0.4647   960959277
# 2025-01-31  0.4665  0.5226  0.4435  0.5054         0.5054  1591983949
# 2025-02-07  0.4919  0.5088  0.4911  0.5008         0.5008   247712741
#
#            dividend_amount
# date
# 2005-02-28          0.0000
# 2005-03-31          0.0000
# 2005-04-29          0.1412
# 2005-05-31          0.0000
# 2005-06-30          0.0000
# ...                    ...
# 2024-10-31          0.0000
# 2024-11-29          0.0000
# 2024-12-31          0.0000
# 2025-01-31          0.0000
# 2025-02-07          0.0000
#
# [241 rows x 7 columns]

# %%
#salvar meu csv
output_path = r"C:\Users\carlo\Documents\Curso_DataOps\GALP_PROJECT\data\monthly_adjusted_data.csv"
df.to_csv(output_path)
print(df.head())
# Out:
#               open    high     low   close adjusted_close    volume  \
# date
# 2005-02-28  2.1198  2.1599  2.0798  2.1100         6.9652  43777814
# 2005-03-31  2.1001  2.1901  2.0699  2.1001         6.9322  59038597
# 2005-04-29  2.0798  2.1500  2.0502  2.0798         6.9826  25893934
# 2005-05-31  2.0902  2.1401  2.0798  2.1001         7.0497  43967714
# 2005-06-30  2.1001  2.1401  2.0298  2.1198         7.1168  34542762
#
#            dividend_amount
# date
# 2005-02-28          0.0000
# 2005-03-31          0.0000
# 2005-04-29          0.1412
# 2005-05-31          0.0000
# 2005-06-30          0.0000
